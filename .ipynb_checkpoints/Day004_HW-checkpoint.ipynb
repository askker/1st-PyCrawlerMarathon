# %% [markdown]
# # 利用 Python 存取 API
#
#
# * 了解 Server Client 的架構與溝通方法
# * 知道 HTTP Request & Response 的內容
# * 什麼是 API？如何用 Python 程式存取 API 資料

# %% [markdown]
# ## 作業目標
#
# * 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異
# * 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#     * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
#     * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)

# %% [markdown]
# ### 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異

# %%
import requests

r = requests.get('https://api.github.com/events')
r.text
# Out:
# '[{"id":"10995263311","type":"WatchEvent","actor":{"id":26609457,"login":"shiaru","display_login":"shiaru","gravatar_id":"","url":"https://api.github.com/users/shiaru","avatar_url":"https://avatars.githubusercontent.com/u/26609457?"},"repo":{"id":210560463,"name":"line/vue-pivot-table-plus","url":"https://api.github.com/repos/line/vue-pivot-table-plus"},"payload":{"action":"started"},"public":true,"created_at":"2019-12-03T02:34:57Z","org":{"id":13128444,"login":"line","gravatar_id":"","url":"https://api.github.com/orgs/line","avatar_url":"https://avatars.githubusercontent.com/u/13128444?"}},{"id":"10995263315","type":"CreateEvent","actor":{"id":43606066,"login":"ChoiBU","display_login":"ChoiBU","gravatar_id":"","url":"https://api.github.com/users/ChoiBU","avatar_url":"https://avatars.githubusercontent.com/u/43606066?"},"repo":{"id":224194766,"name":"ChoiBU/choibu.github.io","url":"https://api.github.com/repos/ChoiBU/choibu.github.io"},"payload":{"ref":"gh-pages","ref_type":"branch","master_branch":"master","description":null,"pusher_type":"user"},"public":true,"created_at":"2019-12-03T02:34:57Z"},{"id":"10995263310","type":"PullRequestReviewCommentEvent","actor":{"id":7504421,"login":"bangerth","display_login":"bangerth","gravatar_id":"","url":"https://api.github.com/users/bangerth","avatar_url":"https://avatars.githubusercontent.com/u/7504421?"},"repo":{"id":21943980,"name":"dealii/dealii","url":"https://api.github.com/repos/dealii/dealii"},"payload":{"action":"created","comment":{"url":"https://api.github.com/repos/dealii/dealii/pulls/comments/352959033","pull_request_review_id":325864772,"id":352959033,"node_id":"MDI0OlB1bGxSZXF1ZXN0UmV2aWV3Q29tbWVudDM1Mjk1OTAzMw==","diff_hunk":"@@ -2309,7 +2310,8 @@ namespace DoFTools\\n   void\\n   map_dofs_to_support_points(const Mapping<dim, spacedim> &   mapping,\\n                              const DoFHandler<dim, spacedim> &dof_handler,\\n-                             std::vector<Point<spacedim>> &   support_points);\\n+                             std::vector<Point<spacedim>> &   support_points,\\n+                             const ComponentMask &mask = ComponentMask());","path":"include/deal.II/dofs/dof_tools.h","position":14,"original_position":14,"commit_id":"7158719c5e7cfaf4fe55403b13191e92b93017d3","original_commit_id":"7158719c5e7cfaf4fe55403b13191e92b93017d3","user":{"login":"bangerth","id":7504421,"node_id":"MDQ6VXNlcjc1MDQ0MjE=","avatar_url":"https://avatars2.githubusercontent.com/u/7504421?v=4","gravatar_id":"","url":"https://api.github.com/users/bangerth","html_url":"https://github.com/bangerth","followers_url":"https://api.github.com/users/bangerth/followers","following_url":"https://api.github.com/users/bangerth/following{/other_user}","gists_url":"https://api.github.com/users/bangerth/gists{/gist_id}","starred_url":"https://api.github.com/users/bangerth/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/bangerth/subscriptions","organizations_url":"https://api.github.com/users/bangerth/orgs","repos_url":"https://api.github.com/users/bangerth/repos","events_url":"https://api.github.com/users/bangerth/events{/privacy}","received_events_url":"https://api.github.com/users/bangerth/received_events","type":"User","site_admin":false},"body":"Can you document the additional argument?","created_at":"2019-12-03T02:32:24Z","updated_at":"2019-12-03T02:34:57Z","html_url":"https://github.com/dealii/dealii/pull/9071#discussion_r352959033","pull_request_url":"https://api.github.com/repos/dealii/dealii/pulls/9071","author_association":"MEMBER","_links":{"self":{"href":"https://api.github.com/repos/dealii/dealii/pulls/comments/352959033"},"html":{"href":"https://github.com/dealii/dealii/pull/9071#discussion_r352959033"},"pull_request":{"href":"https://api.github.com/repos/dealii/dealii/pulls/9071"}}},"pull_request":{"url":"https://api.github.com/repos/dealii/dealii/pulls/9071","id":344179780,"node_id":"MDExOlB1bGxSZXF1ZXN0MzQ0MTc5Nzgw","html_url":"https://github. ...

# %%
import json

json.loads(r.text)
# Out:
# [{'id': '10995263311',
#   'type': 'WatchEvent',
#   'actor': {'id': 26609457,
#    'login': 'shiaru',
#    'display_login': 'shiaru',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/shiaru',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/26609457?'},
#   'repo': {'id': 210560463,
#    'name': 'line/vue-pivot-table-plus',
#    'url': 'https://api.github.com/repos/line/vue-pivot-table-plus'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2019-12-03T02:34:57Z',
#   'org': {'id': 13128444,
#    'login': 'line',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/line',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/13128444?'}},
#  {'id': '10995263315',
#   'type': 'CreateEvent',
#   'actor': {'id': 43606066,
#    'login': 'ChoiBU',
#    'display_login': 'ChoiBU',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ChoiBU',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/43606066?'},
#   'repo': {'id': 224194766,
#    'name': 'ChoiBU/choibu.github.io',
#    'url': 'https://api.github.com/repos/ChoiBU/choibu.github.io'},
#   'payload': {'ref': 'gh-pages',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2019-12-03T02:34:57Z'},
#  {'id': '10995263310',
#   'type': 'PullRequestReviewCommentEvent',
#   'actor': {'id': 7504421,
#    'login': 'bangerth',
#    'display_login': 'bangerth',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/bangerth',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/7504421?'},
#   'repo': {'id': 21943980,
#    'name': 'dealii/dealii',
#    'url': 'https://api.github.com/repos/dealii/dealii'},
#   'payload': {'action': 'created',
#    'comment': {'url': 'https://api.github.com/repos/dealii/dealii/pulls/comments/352959033',
#     'pull_request_review_id': 325864772,
#     'id': 352959033,
#     'node_id': 'MDI0OlB1bGxSZXF1ZXN0UmV2aWV3Q29tbWVudDM1Mjk1OTAzMw==',
#     'diff_hunk': '@@ -2309,7 +2310,8 @@ namespace DoFTools\n   void\n   map_dofs_to_support_points(const Mapping<dim, spacedim> &   mapping,\n                              const DoFHandler<dim, spacedim> &dof_handler,\n-                             std::vector<Point<spacedim>> &   support_points);\n+                             std::vector<Point<spacedim>> &   support_points,\n+                             const ComponentMask &mask = ComponentMask());',
#     'path': 'include/deal.II/dofs/dof_tools.h',
#     'position': 14,
#     'original_position': 14,
#     'commit_id': '7158719c5e7cfaf4fe55403b13191e92b93017d3',
#     'original_commit_id': '7158719c5e7cfaf4fe55403b13191e92b93017d3',
#     'user': {'login': 'bangerth',
#      'id': 7504421,
#      'node_id': 'MDQ6VXNlcjc1MDQ0MjE=',
#      'avatar_url': 'https://avatars2.githubusercontent.com/u/7504421?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/bangerth',
#      'html_url': 'https://github.com/bangerth',
#      'followers_url': 'https://api.github.com/users/bangerth/followers',
#      'following_url': 'https://api.github.com/users/bangerth/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/bangerth/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/bangerth/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/bangerth/subscriptions',
#      'organizations_url': 'https://api.github.com/users/bangerth/orgs',
#      'repos_url': 'https://api.github.com/users/bangerth/repos',
#      'events_url': 'https://api.github.com/users/bangerth/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/bangerth/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': 'Can you document the additional argument?',
#     'created_at': '2019-12-03T02:32:24Z',
#     'updated_at': '2019-12-03T02:34:57Z',
#     'html_url': 'https://github.com/dealii/dealii/pull/9071#discussion_r352959033',
#     'pull_request_url': 'https://api.github.com/repos/dealii/dealii/pulls/9071',
#     'author_association': 'MEMBER',
#     '_links': {'self': {'href': 'https://api.github.com/repos/dealii/dealii/pulls/comments/352959033'},
#      'html': {'href': 'https://github.com/dealii/dealii/pull/9071#discussion_r352959033'},
#      'pull_request': {'href': 'https://api.github.com/repos/dealii/dealii/pulls/9071'}}},
#    'pull_request': {'url': 'https://api.github.com/repos/dealii/dealii/pulls/9071',
#     'id': 344179780,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0MzQ0MTc5Nzgw',
#     'html_url': 'https://github.com/dealii/dealii/pull/9071',
#     'diff_url': 'https://github.com/dealii/dealii/pull/9071.diff',
#     'patch_url': 'https://github.com/dealii/dealii/pull/9071.patch',
#     'issue_url': 'https://api.github.com/repos/dealii/dealii/issues/9071',
#     'number': 9071,
#     'state': 'open',
#     'locked': False,
#     'title': 'Map dofs to support points',
#     'user': {'login': 'luca-heltai',
#      'id': 2919756,
#      'node_id': 'MDQ6VXNlcjI5MTk3NTY=',
#      'avatar_url': 'https://avatars1.githubusercontent.com/u/2919756?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/luca-heltai',
#      'html_url': 'https://github.com/luca-heltai',
#      'followers_url': 'https://api.github.com/users/luca-heltai/followers',
#      'following_url': 'https://api.github.com/users/luca-heltai/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/luca-heltai/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/luca-heltai/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/luca-heltai/subscriptions',
#      'organizations_url': 'https://api.github.com/users/luca-heltai/orgs',
#      'repos_url': 'https://api.github.com/users/luca-heltai/repos',
#      'events_url': 'https://api.github.com/users/luca-heltai/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/luca-heltai/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': 'Same function as the old ones, but returns an IndexSet\r\nper component.',
#     'created_at': '2019-11-21T18:48:54Z',
#     'updated_at': '2019-12-03T02:34:57Z',
#     'closed_at': None,
#     'merged_at': None,
#     'merge_commit_sha': 'd4ee07fdd9f5b2372b046ce5d5848ad3f549c2af',
#     'assignee': {'login': 'blaisb',
#      'id': 7850307,
#      'node_id': 'MDQ6VXNlcjc4NTAzMDc=',
#      'avatar_url': 'https://avatars2.githubusercontent.com/u/7850307?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/blaisb',
#      'html_url': 'https://github.com/blaisb',
#      'followers_url': 'https://api.github.com/users/blaisb/followers',
#      'following_url': 'https://api.github.com/users/blaisb/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/blaisb/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/blaisb/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/blaisb/subscriptions',
#      'organizations_url': 'https://api.github.com/users/blaisb/orgs',
#      'repos_url': 'https://api.github.com/users/blaisb/repos',
#      'events_url': 'https://api.github.com/users/blaisb/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/blaisb/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'assignees': [{'login': 'blaisb',
#       'id': 7850307,
#       'node_id': 'MDQ6VXNlcjc4NTAzMDc=',
#       'avatar_url': 'https://avatars2.githubusercontent.com/u/7850307?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/blaisb',
#       'html_url': 'https://github.com/blaisb',
#       'followers_url': 'https://api.github.com/users/blaisb/followers',
#       'following_url': 'https://api.github.com/users/blaisb/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/blaisb/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/blaisb/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/blaisb/subscriptions',
#       'organizations_url': 'https://api.github.com/users/blaisb/orgs',
#       'repos_url': 'https://api.github.com/users/blaisb/repos',
#       'events_url': 'https://api.github.com/users/blaisb/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/blaisb/received_events',
#       'type': 'User',
#       'site_admin': False}],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [{'id': 538380347,
#       'node_id': 'MDU6TGFiZWw1MzgzODAzNDc=',
#       'url': 'https://api.github.com/repos/dealii/dealii/labels/DoFs',
#       'name': 'DoFs',
#       'color': '8effa7',
#       'default': False,
#       'description': ''},
#      {'id': 252576878,
#       'node_id': 'MDU6TGFiZWwyNTI1NzY4Nzg=',
#       'url': 'https://api.github.com/repos/dealii/dealii/labels/WIP%20:warning:',
#       'name': 'WIP :warning:',
#       'color': '0052cc',
#       'default': False,
#       'description': ''}],
#     'milestone': None,
#     'commits_url': 'https://api.github.com/repos/dealii/dealii/pulls/9071/commits',
#     'review_comments_url': 'https://api.github.com/repos/dealii/dealii/pulls/9071/comments',
#     'review_comment_url': 'https://api.github.com/repos/dealii/dealii/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/dealii/dealii/issues/9071/comments',
#     'statuses_url': 'https://api.github.com/repos/dealii/dealii/statuses/7158719c5e7cfaf4fe55403b13191e92b93017d3',
#     'head': {'label': 'luca-heltai:map-dofs-to-support-points-mask',
#      'ref': 'map-dofs-to-support-points-mask',
#      'sha': '7158719c5e7cfaf4fe55403b13191e92b93017d3',
#      'user': {'login': 'luca-heltai',
#       'id': 2919756,
#       'node_id': 'MDQ6VXNlcjI5MTk3NTY=',
#       'avatar_url': 'https://avatars1.githubusercontent.com/u/2919756?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/luca-heltai',
#       'html_url': 'https://github.com/luca-heltai',
#       'followers_url': 'https://api.github.com/users/luca-heltai/followers',
#       'following_url': 'https://api.github.com/users/luca-heltai/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/luca-heltai/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/luca-heltai/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/luca-heltai/subscriptions',
#       'organizations_url': 'https://api.github.com/users/luca-heltai/orgs',
#       'repos_url': 'https://api.github.com/users/luca-heltai/repos',
#       'events_url': 'https://api.github.com/users/luca-heltai/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/luca-heltai/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 22053864,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkyMjA1Mzg2NA==',
#       'name': 'dealii',
#       'full_name': 'luca-heltai/dealii',
#       'private': False,
#       'owner': {'login': 'luca-heltai',
#        'id': 2919756,
#        'node_id': 'MDQ6VXNlcjI5MTk3NTY=',
#        'avatar_url': 'https://avatars1.githubusercontent.com/u/2919756?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/luca-heltai',
#        'html_url': 'https://github.com/luca-heltai',
#        'followers_url': 'https://api.github.com/users/luca-heltai/followers',
#        'following_url': 'https://api.github.com/users/luca-heltai/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/luca-heltai/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/luca-heltai/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/luca-heltai/subscriptions',
#        'organizations_url': 'https://api.github.com/users/luca-heltai/orgs',
#        'repos_url': 'https://api.github.com/users/luca-heltai/repos',
#        'events_url': 'https://api.github.com/users/luca-heltai/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/luca-heltai/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/luca-heltai/dealii',
#       'description': None,
#       'fork': True,
#       'url': 'https://api.github.com/repos/luca-heltai/dealii',
#       'forks_url': 'https://api.github.com/repos/luca-heltai/dealii/forks',
#       'keys_url': 'https://api.github.com/repos/luca-heltai/dealii/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/luca-heltai/dealii/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/luca-heltai/dealii/teams',
#       'hooks_url': 'https://api.github.com/repos/luca-heltai/dealii/hooks',
#       'issue_events_url': 'https://api.github.com/repos/luca-heltai/dealii/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/luca-heltai/dealii/events',
#       'assignees_url': 'https://api.github.com/repos/luca-heltai/dealii/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/luca-heltai/dealii/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/luca-heltai/dealii/tags',
#       'blobs_url': 'https://api.github.com/repos/luca-heltai/dealii/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/luca-heltai/dealii/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/luca-heltai/dealii/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/luca-heltai/dealii/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/luca-heltai/dealii/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/luca-heltai/dealii/languages',
#       'stargazers_url': 'https://api.github.com/repos/luca-heltai/dealii/stargazers',
#       'contributors_url': 'https://api.github.com/repos/luca-heltai/dealii/contributors',
#       'subscribers_url': 'https://api.github.com/repos/luca-heltai/dealii/subscribers',
#       'subscription_url': 'https://api.github.com/repos/luca-heltai/dealii/subscription',
#       'commits_url': 'https://api.github.com/repos/luca-heltai/dealii/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/luca-heltai/dealii/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/luca-heltai/dealii/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/luca-heltai/dealii/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/luca-heltai/dealii/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/luca-heltai/dealii/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/luca-heltai/dealii/merges',
#       'archive_url': 'https://api.github.com/repos/luca-heltai/dealii/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/luca-heltai/dealii/downloads',
#       'issues_url': 'https://api.github.com/repos/luca-heltai/dealii/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/luca-heltai/dealii/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/luca-heltai/dealii/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/luca-heltai/dealii/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/luca-heltai/dealii/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/luca-heltai/dealii/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/luca-heltai/dealii/deployments',
#       'created_at': '2014-07-21T06:17:40Z',
#       'updated_at': '2019-12-02T23:49:32Z',
#       'pushed_at': '2019-12-02T23:50:23Z',
#       'git_url': 'git://github.com/luca-heltai/dealii.git',
#       'ssh_url': 'git@github.com:luca-heltai/dealii.git',
#       'clone_url': 'https://github.com/luca-heltai/dealii.git',
#       'svn_url': 'https://github.com/luca-heltai/dealii',
#       'homepage': None,
#       'size': 229611,
#       'stargazers_count': 2,
#       'watchers_count': 2,
#       'language': 'C++',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 2,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 5,
#       'license': {'key': 'other',
#        'name': 'Other',
#        'spdx_id': 'NOASSERTION',
#        'url': None,
#        'node_id': 'MDc6TGljZW5zZTA='},
#       'forks': 2,
#       'open_issues': 5,
#       'watchers': 2,
#       'default_branch': 'master'}},
#     'base': {'label': 'dealii:master',
#      'ref': 'master',
#      'sha': '8077dbe9f294dc30e382e7fe30db77cc1d7d2a62',
#      'user': {'login': 'dealii',
#       'id': 7506070,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjc1MDYwNzA=',
#       'avatar_url': 'https://avatars3.githubusercontent.com/u/7506070?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/dealii',
#       'html_url': 'https://github.com/dealii',
#       'followers_url': 'https://api.github.com/users/dealii/followers',
#       'following_url': 'https://api.github.com/users/dealii/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/dealii/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/dealii/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/dealii/subscriptions',
#       'organizations_url': 'https://api.github.com/users/dealii/orgs',
#       'repos_url': 'https://api.github.com/users/dealii/repos',
#       'events_url': 'https://api.github.com/users/dealii/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/dealii/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 21943980,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkyMTk0Mzk4MA==',
#       'name': 'dealii',
#       'full_name': 'dealii/dealii',
#       'private': False,
#       'owner': {'login': 'dealii',
#        'id': 7506070,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjc1MDYwNzA=',
#        'avatar_url': 'https://avatars3.githubusercontent.com/u/7506070?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/dealii',
#        'html_url': 'https://github.com/dealii',
#        'followers_url': 'https://api.github.com/users/dealii/followers',
#        'following_url': 'https://api.github.com/users/dealii/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/dealii/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/dealii/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/dealii/subscriptions',
#        'organizations_url': 'https://api.github.com/users/dealii/orgs',
#        'repos_url': 'https://api.github.com/users/dealii/repos',
#        'events_url': 'https://api.github.com/users/dealii/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/dealii/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/dealii/dealii',
#       'description': 'The development repository for the deal.II finite element library.',
#       'fork': False,
#       'url': 'https://api.github.com/repos/dealii/dealii',
#       'forks_url': 'https://api.github.com/repos/dealii/dealii/forks',
#       'keys_url': 'https://api.github.com/repos/dealii/dealii/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/dealii/dealii/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/dealii/dealii/teams',
#       'hooks_url': 'https://api.github.com/repos/dealii/dealii/hooks',
#       'issue_events_url': 'https://api.github.com/repos/dealii/dealii/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/dealii/dealii/events',
#       'assignees_url': 'https://api.github.com/repos/dealii/dealii/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/dealii/dealii/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/dealii/dealii/tags',
#       'blobs_url': 'https://api.github.com/repos/dealii/dealii/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/dealii/dealii/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/dealii/dealii/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/dealii/dealii/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/dealii/dealii/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/dealii/dealii/languages',
#       'stargazers_url': 'https://api.github.com/repos/dealii/dealii/stargazers',
#       'contributors_url': 'https://api.github.com/repos/dealii/dealii/contributors',
#       'subscribers_url': 'https://api.github.com/repos/dealii/dealii/subscribers',
#       'subscription_url': 'https://api.github.com/repos/dealii/dealii/subscription',
#       'commits_url': 'https://api.github.com/repos/dealii/dealii/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/dealii/dealii/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/dealii/dealii/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/dealii/dealii/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/dealii/dealii/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/dealii/dealii/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/dealii/dealii/merges',
#       'archive_url': 'https://api.github.com/repos/dealii/dealii/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/dealii/dealii/downloads',
#       'issues_url': 'https://api.github.com/repos/dealii/dealii/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/dealii/dealii/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/dealii/dealii/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/dealii/dealii/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/dealii/dealii/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/dealii/dealii/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/dealii/dealii/deployments',
#       'created_at': '2014-07-17T14:00:26Z',
#       'updated_at': '2019-12-03T01:04:21Z',
#       'pushed_at': '2019-12-03T02:07:49Z',
#       'git_url': 'git://github.com/dealii/dealii.git',
#       'ssh_url': 'git@github.com:dealii/dealii.git',
#       'clone_url': 'https://github.com/dealii/dealii.git',
#       'svn_url': 'https://github.com/dealii/dealii',
#       'homepage': 'https://www.dealii.org/',
#       'size': 228116,
#       'stargazers_count': 556,
#       'watchers_count': 556,
#       'language': 'C++',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 426,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 450,
#       'license': {'key': 'other',
#        'name': 'Other',
#        'spdx_id': 'NOASSERTION',
#        'url': None,
#        'node_id': 'MDc6TGljZW5zZTA='},
#       'forks': 426,
#       'open_issues': 450,
#       'watchers': 556,
#       'default_branch': 'master'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/dealii/dealii/pulls/9071'},
#      'html': {'href': 'https://github.com/dealii/dealii/pull/9071'},
#      'issue': {'href': 'https://api.github.com/repos/dealii/dealii/issues/9071'},
#      'comments': {'href': 'https://api.github.com/repos/dealii/dealii/issues/9071/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/dealii/dealii/pulls/9071/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/dealii/dealii/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/dealii/dealii/pulls/9071/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/dealii/dealii/statuses/7158719c5e7cfaf4fe55403b13191e92b93017d3'}},
#     'author_association': 'MEMBER'}},
#   'public': True,
#   'created_at': '2019-12-03T02:32:24Z',
#   'org': {'id': 7506070,
#    'login': 'dealii',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/dealii',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/7506070?'}},
#  {'id': '10995263305',
#   'type': 'CreateEvent',
#   'actor': {'id': 18106556,
#    'login': 'KangtaeKim',
#    'display_login': 'KangtaeKim',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/KangtaeKim',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/18106556?'},
#   'repo': {'id': 225513589,
#    'name': 'KangtaeKim/kangtaekim.github.com',
#    'url': 'https://api.github.com/repos/KangtaeKim/kangtaekim.github.com'},
#   'payload': {'ref': 'master',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2019-12-03T02:34:57Z'},
#  {'id': '10995263302',
#   'type': 'PullRequestReviewCommentEvent',
#   'actor': {'id': 7504421,
#    'login': 'bangerth',
#    'display_login': 'bangerth',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/bangerth',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/7504421?'},
#   'repo': {'id': 21943980,
#    'name': 'dealii/dealii',
#    'url': 'https://api.github.com/repos/dealii/dealii'},
#   'payload': {'action': 'created',
#    'comment': {'url': 'https://api.github.com/repos/dealii/dealii/pulls/comments/352958949',
#     'pull_request_review_id': 325864772,
#     'id': 352958949,
#     'node_id': 'MDI0OlB1bGxSZXF1ZXN0UmV2aWV3Q29tbWVudDM1Mjk1ODk0OQ==',
#     'diff_hunk': '@@ -26,6 +26,7 @@\n #include <deal.II/dofs/dof_handler.h>\n \n #include <deal.II/fe/component_mask.h>\n+#include <deal.II/fe/fe_values.h>',
#     'path': 'include/deal.II/dofs/dof_tools.h',
#     'position': 4,
#     'original_position': 4,
#     'commit_id': '7158719c5e7cfaf4fe55403b13191e92b93017d3',
#     'original_commit_id': '7158719c5e7cfaf4fe55403b13191e92b93017d3',
#     'user': {'login': 'bangerth',
#      'id': 7504421,
#      'node_id': 'MDQ6VXNlcjc1MDQ0MjE=',
#      'avatar_url': 'https://avatars2.githubusercontent.com/u/7504421?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/bangerth',
#      'html_url': 'https://github.com/bangerth',
#      'followers_url': 'https://api.github.com/users/bangerth/followers',
#      'following_url': 'https://api.github.com/users/bangerth/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/bangerth/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/bangerth/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/bangerth/subscriptions',
#      'organizations_url': 'https://api.github.com/users/bangerth/orgs',
#      'repos_url': 'https://api.github.com/users/bangerth/repos',
#      'events_url': 'https://api.github.com/users/bangerth/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/bangerth/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': 'I think  you only want to `#include <deal.II/fe/component_mask.h>`.',
#     'created_at': '2019-12-03T02:31:59Z',
#     'updated_at': '2019-12-03T02:34:57Z',
#     'html_url': 'https://github.com/dealii/dealii/pull/9071#discussion_r352958949',
#     'pull_request_url': 'https://api.github.com/repos/dealii/dealii/pulls/9071',
#     'author_association': 'MEMBER',
#     '_links': {'self': {'href': 'https://api.github.com/repos/dealii/dealii/pulls/comments/352958949'},
#      'html': {'href': 'https://github.com/dealii/dealii/pull/9071#discussion_r352958949'},
#      'pull_request': {'href': 'https://api.github.com/repos/dealii/dealii/pulls/9071'}}},
#    'pull_request': {'url': 'https://api.github.com/repos/dealii/dealii/pulls/9071',
#     'id': 344179780,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0MzQ0MTc5Nzgw',
#     'html_url': 'https://github.com/dealii/dealii/pull/9071',
#     'diff_url': 'https://github.com/dealii/dealii/pull/9071.diff',
#     'patch_url': 'https://github.com/dealii/dealii/pull/9071.patch',
#     'issue_url': 'https://api.github.com/repos/dealii/dealii/issues/9071',
#     'number': 9071,
#     'state': 'open',
#     'locked': False,
#     'title': 'Map dofs to support points',
#     'user': {'login': 'luca-heltai',
#      'id': 2919756,
#      'node_id': 'MDQ6VXNlcjI5MTk3NTY=',
#      'avatar_url': 'https://avatars1.githubusercontent.com/u/2919756?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/luca-heltai',
#      'html_url': 'https://github.com/luca-heltai',
#      'followers_url': 'https://api.github.com/users/luca-heltai/followers',
#      'following_url': 'https://api.github.com/users/luca-heltai/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/luca-heltai/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/luca-heltai/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/luca-heltai/subscriptions',
#      'organizations_url': 'https://api.github.com/users/luca-heltai/orgs',
#      'repos_url': 'https://api.github.com/users/luca-heltai/repos',
#      'events_url': 'https://api.github.com/users/luca-heltai/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/luca-heltai/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': 'Same function as the old ones, but returns an IndexSet\r\nper component.',
#     'created_at': '2019-11-21T18:48:54Z',
#     'updated_at': '2019-12-03T02:34:57Z',
#     'closed_at': None,
#     'merged_at': None,
#     'merge_commit_sha': 'd4ee07fdd9f5b2372b046ce5d5848ad3f549c2af',
#     'assignee': {'login': 'blaisb',
#      'id': 7850307,
#      'node_id': 'MDQ6VXNlcjc4NTAzMDc=',
#      'avatar_url': 'https://avatars2.githubusercontent.com/u/7850307?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/blaisb',
#      'html_url': 'https://github.com/blaisb',
#      'followers_url': 'https://api.github.com/users/blaisb/followers',
#      'following_url': 'https://api.github.com/users/blaisb/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/blaisb/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/blaisb/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/blaisb/subscriptions',
#      'organizations_url': 'https://api.github.com/users/blaisb/orgs',
#      'repos_url': 'https://api.github.com/users/blaisb/repos',
#      'events_url': 'https://api.github.com/users/blaisb/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/blaisb/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'assignees': [{'login': 'blaisb',
#       'id': 7850307,
#       'node_id': 'MDQ6VXNlcjc4NTAzMDc=',
#       'avatar_url': 'https://avatars2.githubusercontent.com/u/7850307?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/blaisb',
#       'html_url': 'https://github.com/blaisb',
#       'followers_url': 'https://api.github.com/users/blaisb/followers',
#       'following_url': 'https://api.github.com/users/blaisb/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/blaisb/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/blaisb/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/blaisb/subscriptions',
#       'organizations_url': 'https://api.github.com/users/blaisb/orgs',
#       'repos_url': 'https://api.github.com/users/blaisb/repos',
#       'events_url': 'https://api.github.com/users/blaisb/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/blaisb/received_events',
#       'type': 'User',
#       'site_admin': False}],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [{'id': 538380347,
#       'node_id': 'MDU6TGFiZWw1MzgzODAzNDc=',
#       'url': 'https://api.github.com/repos/dealii/dealii/labels/DoFs',
#       'name': 'DoFs',
#       'color': '8effa7',
#       'default': False,
#       'description': ''},
#      {'id': 252576878,
#       'node_id': 'MDU6TGFiZWwyNTI1NzY4Nzg=',
#       'url': 'https://api.github.com/repos/dealii/dealii/labels/WIP%20:warning:',
#       'name': 'WIP :warning:',
#       'color': '0052cc',
#       'default': False,
#       'description': ''}],
#     'milestone': None,
#     'commits_url': 'https://api.github.com/repos/dealii/dealii/pulls/9071/commits',
#     'review_comments_url': 'https://api.github.com/repos/dealii/dealii/pulls/9071/comments',
#     'review_comment_url': 'https://api.github.com/repos/dealii/dealii/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/dealii/dealii/issues/9071/comments',
#     'statuses_url': 'https://api.github.com/repos/dealii/dealii/statuses/7158719c5e7cfaf4fe55403b13191e92b93017d3',
#     'head': {'label': 'luca-heltai:map-dofs-to-support-points-mask',
#      'ref': 'map-dofs-to-support-points-mask',
#      'sha': '7158719c5e7cfaf4fe55403b13191e92b93017d3',
#      'user': {'login': 'luca-heltai',
#       'id': 2919756,
#       'node_id': 'MDQ6VXNlcjI5MTk3NTY=',
#       'avatar_url': 'https://avatars1.githubusercontent.com/u/2919756?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/luca-heltai',
#       'html_url': 'https://github.com/luca-heltai',
#       'followers_url': 'https://api.github.com/users/luca-heltai/followers',
#       'following_url': 'https://api.github.com/users/luca-heltai/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/luca-heltai/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/luca-heltai/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/luca-heltai/subscriptions',
#       'organizations_url': 'https://api.github.com/users/luca-heltai/orgs',
#       'repos_url': 'https://api.github.com/users/luca-heltai/repos',
#       'events_url': 'https://api.github.com/users/luca-heltai/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/luca-heltai/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 22053864,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkyMjA1Mzg2NA==',
#       'name': 'dealii',
#       'full_name': 'luca-heltai/dealii',
#       'private': False,
#       'owner': {'login': 'luca-heltai',
#        'id': 2919756,
#        'node_id': 'MDQ6VXNlcjI5MTk3NTY=',
#        'avatar_url': 'https://avatars1.githubusercontent.com/u/2919756?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/luca-heltai',
#        'html_url': 'https://github.com/luca-heltai',
#        'followers_url': 'https://api.github.com/users/luca-heltai/followers',
#        'following_url': 'https://api.github.com/users/luca-heltai/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/luca-heltai/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/luca-heltai/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/luca-heltai/subscriptions',
#        'organizations_url': 'https://api.github.com/users/luca-heltai/orgs',
#        'repos_url': 'https://api.github.com/users/luca-heltai/repos',
#        'events_url': 'https://api.github.com/users/luca-heltai/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/luca-heltai/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/luca-heltai/dealii',
#       'description': None,
#       'fork': True,
#       'url': 'https://api.github.com/repos/luca-heltai/dealii',
#       'forks_url': 'https://api.github.com/repos/luca-heltai/dealii/forks',
#       'keys_url': 'https://api.github.com/repos/luca-heltai/dealii/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/luca-heltai/dealii/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/luca-heltai/dealii/teams',
#       'hooks_url': 'https://api.github.com/repos/luca-heltai/dealii/hooks',
#       'issue_events_url': 'https://api.github.com/repos/luca-heltai/dealii/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/luca-heltai/dealii/events',
#       'assignees_url': 'https://api.github.com/repos/luca-heltai/dealii/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/luca-heltai/dealii/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/luca-heltai/dealii/tags',
#       'blobs_url': 'https://api.github.com/repos/luca-heltai/dealii/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/luca-heltai/dealii/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/luca-heltai/dealii/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/luca-heltai/dealii/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/luca-heltai/dealii/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/luca-heltai/dealii/languages',
#       'stargazers_url': 'https://api.github.com/repos/luca-heltai/dealii/stargazers',
#       'contributors_url': 'https://api.github.com/repos/luca-heltai/dealii/contributors',
#       'subscribers_url': 'https://api.github.com/repos/luca-heltai/dealii/subscribers',
#       'subscription_url': 'https://api.github.com/repos/luca-heltai/dealii/subscription',
#       'commits_url': 'https://api.github.com/repos/luca-heltai/dealii/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/luca-heltai/dealii/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/luca-heltai/dealii/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/luca-heltai/dealii/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/luca-heltai/dealii/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/luca-heltai/dealii/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/luca-heltai/dealii/merges',
#       'archive_url': 'https://api.github.com/repos/luca-heltai/dealii/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/luca-heltai/dealii/downloads',
#       'issues_url': 'https://api.github.com/repos/luca-heltai/dealii/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/luca-heltai/dealii/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/luca-heltai/dealii/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/luca-heltai/dealii/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/luca-heltai/dealii/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/luca-heltai/dealii/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/luca-heltai/dealii/deployments',
#       'created_at': '2014-07-21T06:17:40Z',
#       'updated_at': '2019-12-02T23:49:32Z',
#       'pushed_at': '2019-12-02T23:50:23Z',
#       'git_url': 'git://github.com/luca-heltai/dealii.git',
#       'ssh_url': 'git@github.com:luca-heltai/dealii.git',
#       'clone_url': 'https://github.com/luca-heltai/dealii.git',
#       'svn_url': 'https://github.com/luca-heltai/dealii',
#       'homepage': None,
#       'size': 229611,
#       'stargazers_count': 2,
#       'watchers_count': 2,
#       'language': 'C++',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 2,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 5,
#       'license': {'key': 'other',
#        'name': 'Other',
#        'spdx_id': 'NOASSERTION',
#        'url': None,
#        'node_id': 'MDc6TGljZW5zZTA='},
#       'forks': 2,
#       'open_issues': 5,
#       'watchers': 2,
#       'default_branch': 'master'}},
#     'base': {'label': 'dealii:master',
#      'ref': 'master',
#      'sha': '8077dbe9f294dc30e382e7fe30db77cc1d7d2a62',
#      'user': {'login': 'dealii',
#       'id': 7506070,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjc1MDYwNzA=',
#       'avatar_url': 'https://avatars3.githubusercontent.com/u/7506070?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/dealii',
#       'html_url': 'https://github.com/dealii',
#       'followers_url': 'https://api.github.com/users/dealii/followers',
#       'following_url': 'https://api.github.com/users/dealii/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/dealii/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/dealii/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/dealii/subscriptions',
#       'organizations_url': 'https://api.github.com/users/dealii/orgs',
#       'repos_url': 'https://api.github.com/users/dealii/repos',
#       'events_url': 'https://api.github.com/users/dealii/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/dealii/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 21943980,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkyMTk0Mzk4MA==',
#       'name': 'dealii',
#       'full_name': 'dealii/dealii',
#       'private': False,
#       'owner': {'login': 'dealii',
#        'id': 7506070,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjc1MDYwNzA=',
#        'avatar_url': 'https://avatars3.githubusercontent.com/u/7506070?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/dealii',
#        'html_url': 'https://github.com/dealii',
#        'followers_url': 'https://api.github.com/users/dealii/followers',
#        'following_url': 'https://api.github.com/users/dealii/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/dealii/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/dealii/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/dealii/subscriptions',
#        'organizations_url': 'https://api.github.com/users/dealii/orgs',
#        'repos_url': 'https://api.github.com/users/dealii/repos',
#        'events_url': 'https://api.github.com/users/dealii/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/dealii/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/dealii/dealii',
#       'description': 'The development repository for the deal.II finite element library.',
#       'fork': False,
#       'url': 'https://api.github.com/repos/dealii/dealii',
#       'forks_url': 'https://api.github.com/repos/dealii/dealii/forks',
#       'keys_url': 'https://api.github.com/repos/dealii/dealii/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/dealii/dealii/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/dealii/dealii/teams',
#       'hooks_url': 'https://api.github.com/repos/dealii/dealii/hooks',
#       'issue_events_url': 'https://api.github.com/repos/dealii/dealii/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/dealii/dealii/events',
#       'assignees_url': 'https://api.github.com/repos/dealii/dealii/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/dealii/dealii/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/dealii/dealii/tags',
#       'blobs_url': 'https://api.github.com/repos/dealii/dealii/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/dealii/dealii/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/dealii/dealii/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/dealii/dealii/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/dealii/dealii/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/dealii/dealii/languages',
#       'stargazers_url': 'https://api.github.com/repos/dealii/dealii/stargazers',
#       'contributors_url': 'https://api.github.com/repos/dealii/dealii/contributors',
#       'subscribers_url': 'https://api.github.com/repos/dealii/dealii/subscribers',
#       'subscription_url': 'https://api.github.com/repos/dealii/dealii/subscription',
#       'commits_url': 'https://api.github.com/repos/dealii/dealii/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/dealii/dealii/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/dealii/dealii/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/dealii/dealii/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/dealii/dealii/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/dealii/dealii/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/dealii/dealii/merges',
#       'archive_url': 'https://api.github.com/repos/dealii/dealii/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/dealii/dealii/downloads',
#       'issues_url': 'https://api.github.com/repos/dealii/dealii/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/dealii/dealii/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/dealii/dealii/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/dealii/dealii/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/dealii/dealii/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/dealii/dealii/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/dealii/dealii/deployments',
#       'created_at': '2014-07-17T14:00:26Z',
#       'updated_at': '2019-12-03T01:04:21Z',
#       'pushed_at': '2019-12-03T02:07:49Z',
#       'git_url': 'git://github.com/dealii/dealii.git',
#       'ssh_url': 'git@github.com:dealii/dealii.git',
#       'clone_url': 'https://github.com/dealii/dealii.git',
#       'svn_url': 'https://github.com/dealii/dealii',
#       'homepage': 'https://www.dealii.org/',
#       'size': 228116,
#       'stargazers_count': 556,
#       'watchers_count': 556,
#       'language': 'C++',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 426,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 450,
#       'license': {'key': 'other',
#        'name': 'Other',
#        'spdx_id': 'NOASSERTION',
#        'url': None,
#        'node_id': 'MDc6TGljZW5zZTA='},
#       'forks': 426,
#       'open_issues': 450,
#       'watchers': 556,
#       'default_branch': 'master'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/dealii/dealii/pulls/9071'},
#      'html': {'href': 'https://github.com/dealii/dealii/pull/9071'},
#      'issue': {'href': 'https://api.github.com/repos/dealii/dealii/issues/9071'},
#      'comments': {'href': 'https://api.github.com/repos/dealii/dealii/issues/9071/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/dealii/dealii/pulls/9071/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/dealii/dealii/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/dealii/dealii/pulls/9071/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/dealii/dealii/statuses/7158719c5e7cfaf4fe55403b13191e92b93017d3'}},
#     'author_association': 'MEMBER'}},
#   'public': True,
#   'created_at': '2019-12-03T02:31:59Z',
#   'org': {'id': 7506070,
#    'login': 'dealii',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/dealii',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/7506070?'}},
#  {'id': '10995263299',
#   'type': 'PushEvent',
#   'actor': {'id': 16425436,
#    'login': 'wolfleong',
#    'display_login': 'wolfleong',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/wolfleong',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/16425436?'},
#   'repo': {'id': 207521903,
#    'name': 'wolfleong/spring-framework',
#    'url': 'https://api.github.com/repos/wolfleong/spring-framework'},
#   'payload': {'push_id': 4346740698,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/wolfleong',
#    'head': '605d846206b09496a10a3020fec9451408e2c53e',
#    'before': 'd7af877e921213b345c971931090df4ab19e295d',
#    'commits': [{'sha': '605d846206b09496a10a3020fec9451408e2c53e',
#      'author': {'email': '1032304352@qq.com', 'name': 'wolfleong'},
#      'message': 'DefaultConversionService',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/wolfleong/spring-framework/commits/605d846206b09496a10a3020fec9451408e2c53e'}]},
#   'public': True,
#   'created_at': '2019-12-03T02:34:57Z'},
# ...
#       'trees_url': 'https://api.github.com/repos/kyohaifeng/think-cache-redis/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/kyohaifeng/think-cache-redis/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/kyohaifeng/think-cache-redis/languages',
#       'stargazers_url': 'https://api.github.com/repos/kyohaifeng/think-cache-redis/stargazers',
#       'contributors_url': 'https://api.github.com/repos/kyohaifeng/think-cache-redis/contributors',
#       'subscribers_url': 'https://api.github.com/repos/kyohaifeng/think-cache-redis/subscribers',
#       'subscription_url': 'https://api.github.com/repos/kyohaifeng/think-cache-redis/subscription',
#       'commits_url': 'https://api.github.com/repos/kyohaifeng/think-cache-redis/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/kyohaifeng/think-cache-redis/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/kyohaifeng/think-cache-redis/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/kyohaifeng/think-cache-redis/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/kyohaifeng/think-cache-redis/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/kyohaifeng/think-cache-redis/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/kyohaifeng/think-cache-redis/merges',
#       'archive_url': 'https://api.github.com/repos/kyohaifeng/think-cache-redis/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/kyohaifeng/think-cache-redis/downloads',
#       'issues_url': 'https://api.github.com/repos/kyohaifeng/think-cache-redis/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/kyohaifeng/think-cache-redis/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/kyohaifeng/think-cache-redis/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/kyohaifeng/think-cache-redis/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/kyohaifeng/think-cache-redis/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/kyohaifeng/think-cache-redis/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/kyohaifeng/think-cache-redis/deployments',
#       'created_at': '2019-12-03T02:13:49Z',
#       'updated_at': '2019-12-03T02:13:50Z',
#       'pushed_at': '2019-12-03T02:32:42Z',
#       'git_url': 'git://github.com/kyohaifeng/think-cache-redis.git',
#       'ssh_url': 'git@github.com:kyohaifeng/think-cache-redis.git',
#       'clone_url': 'https://github.com/kyohaifeng/think-cache-redis.git',
#       'svn_url': 'https://github.com/kyohaifeng/think-cache-redis',
#       'homepage': '',
#       'size': 11,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': None,
#       'has_issues': False,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': False,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 0,
#       'license': {'key': 'mit',
#        'name': 'MIT License',
#        'spdx_id': 'MIT',
#        'url': 'https://api.github.com/licenses/mit',
#        'node_id': 'MDc6TGljZW5zZTEz'},
#       'forks': 0,
#       'open_issues': 0,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     'base': {'label': 'thinkjs:master',
#      'ref': 'master',
#      'sha': 'a792840ef75f40d62b5b0f74c5f7c5285ab7dd70',
#      'user': {'login': 'thinkjs',
#       'id': 15226349,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjE1MjI2MzQ5',
#       'avatar_url': 'https://avatars3.githubusercontent.com/u/15226349?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/thinkjs',
#       'html_url': 'https://github.com/thinkjs',
#       'followers_url': 'https://api.github.com/users/thinkjs/followers',
#       'following_url': 'https://api.github.com/users/thinkjs/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/thinkjs/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/thinkjs/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/thinkjs/subscriptions',
#       'organizations_url': 'https://api.github.com/users/thinkjs/orgs',
#       'repos_url': 'https://api.github.com/users/thinkjs/repos',
#       'events_url': 'https://api.github.com/users/thinkjs/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/thinkjs/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 86020406,
#       'node_id': 'MDEwOlJlcG9zaXRvcnk4NjAyMDQwNg==',
#       'name': 'think-cache-redis',
#       'full_name': 'thinkjs/think-cache-redis',
#       'private': False,
#       'owner': {'login': 'thinkjs',
#        'id': 15226349,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjE1MjI2MzQ5',
#        'avatar_url': 'https://avatars3.githubusercontent.com/u/15226349?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/thinkjs',
#        'html_url': 'https://github.com/thinkjs',
#        'followers_url': 'https://api.github.com/users/thinkjs/followers',
#        'following_url': 'https://api.github.com/users/thinkjs/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/thinkjs/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/thinkjs/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/thinkjs/subscriptions',
#        'organizations_url': 'https://api.github.com/users/thinkjs/orgs',
#        'repos_url': 'https://api.github.com/users/thinkjs/repos',
#        'events_url': 'https://api.github.com/users/thinkjs/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/thinkjs/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/thinkjs/think-cache-redis',
#       'description': 'Redis adapter for cache for ThinkJS 3.x',
#       'fork': False,
#       'url': 'https://api.github.com/repos/thinkjs/think-cache-redis',
#       'forks_url': 'https://api.github.com/repos/thinkjs/think-cache-redis/forks',
#       'keys_url': 'https://api.github.com/repos/thinkjs/think-cache-redis/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/thinkjs/think-cache-redis/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/thinkjs/think-cache-redis/teams',
#       'hooks_url': 'https://api.github.com/repos/thinkjs/think-cache-redis/hooks',
#       'issue_events_url': 'https://api.github.com/repos/thinkjs/think-cache-redis/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/thinkjs/think-cache-redis/events',
#       'assignees_url': 'https://api.github.com/repos/thinkjs/think-cache-redis/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/thinkjs/think-cache-redis/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/thinkjs/think-cache-redis/tags',
#       'blobs_url': 'https://api.github.com/repos/thinkjs/think-cache-redis/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/thinkjs/think-cache-redis/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/thinkjs/think-cache-redis/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/thinkjs/think-cache-redis/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/thinkjs/think-cache-redis/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/thinkjs/think-cache-redis/languages',
#       'stargazers_url': 'https://api.github.com/repos/thinkjs/think-cache-redis/stargazers',
#       'contributors_url': 'https://api.github.com/repos/thinkjs/think-cache-redis/contributors',
#       'subscribers_url': 'https://api.github.com/repos/thinkjs/think-cache-redis/subscribers',
#       'subscription_url': 'https://api.github.com/repos/thinkjs/think-cache-redis/subscription',
#       'commits_url': 'https://api.github.com/repos/thinkjs/think-cache-redis/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/thinkjs/think-cache-redis/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/thinkjs/think-cache-redis/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/thinkjs/think-cache-redis/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/thinkjs/think-cache-redis/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/thinkjs/think-cache-redis/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/thinkjs/think-cache-redis/merges',
#       'archive_url': 'https://api.github.com/repos/thinkjs/think-cache-redis/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/thinkjs/think-cache-redis/downloads',
#       'issues_url': 'https://api.github.com/repos/thinkjs/think-cache-redis/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/thinkjs/think-cache-redis/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/thinkjs/think-cache-redis/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/thinkjs/think-cache-redis/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/thinkjs/think-cache-redis/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/thinkjs/think-cache-redis/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/thinkjs/think-cache-redis/deployments',
#       'created_at': '2017-03-24T02:50:18Z',
#       'updated_at': '2019-11-20T02:56:55Z',
#       'pushed_at': '2019-11-20T05:47:11Z',
#       'git_url': 'git://github.com/thinkjs/think-cache-redis.git',
#       'ssh_url': 'git@github.com:thinkjs/think-cache-redis.git',
#       'clone_url': 'https://github.com/thinkjs/think-cache-redis.git',
#       'svn_url': 'https://github.com/thinkjs/think-cache-redis',
#       'homepage': '',
#       'size': 11,
#       'stargazers_count': 4,
#       'watchers_count': 4,
#       'language': 'JavaScript',
#       'has_issues': False,
#       'has_projects': False,
#       'has_downloads': True,
#       'has_wiki': False,
#       'has_pages': False,
#       'forks_count': 4,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 1,
#       'license': {'key': 'mit',
#        'name': 'MIT License',
#        'spdx_id': 'MIT',
#        'url': 'https://api.github.com/licenses/mit',
#        'node_id': 'MDc6TGljZW5zZTEz'},
#       'forks': 4,
#       'open_issues': 1,
#       'watchers': 4,
#       'default_branch': 'master'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/thinkjs/think-cache-redis/pulls/2'},
#      'html': {'href': 'https://github.com/thinkjs/think-cache-redis/pull/2'},
#      'issue': {'href': 'https://api.github.com/repos/thinkjs/think-cache-redis/issues/2'},
#      'comments': {'href': 'https://api.github.com/repos/thinkjs/think-cache-redis/issues/2/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/thinkjs/think-cache-redis/pulls/2/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/thinkjs/think-cache-redis/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/thinkjs/think-cache-redis/pulls/2/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/thinkjs/think-cache-redis/statuses/04376429446c686e023daa808782cfbe0687e581'}},
#     'author_association': 'NONE',
#     'merged': False,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': None,
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': True,
#     'commits': 2,
#     'additions': 41,
#     'deletions': 13,
#     'changed_files': 3}},
#   'public': True,
#   'created_at': '2019-12-03T02:34:56Z',
#   'org': {'id': 15226349,
#    'login': 'thinkjs',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/thinkjs',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/15226349?'}},
#  {'id': '10995263209',
#   'type': 'PushEvent',
#   'actor': {'id': 32244520,
#    'login': 'xlaser4j',
#    'display_login': 'xlaser4j',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/xlaser4j',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/32244520?'},
#   'repo': {'id': 149281821,
#    'name': 'xlaser4j/spring-all-demos',
#    'url': 'https://api.github.com/repos/xlaser4j/spring-all-demos'},
#   'payload': {'push_id': 4346740656,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'f72377380590b95c16e2eed1ce7bfa7a690a5484',
#    'before': 'b23e342e0ad6739bb3aa54d9edb79d6739c58da7',
#    'commits': [{'sha': 'f72377380590b95c16e2eed1ce7bfa7a690a5484',
#      'author': {'email': 'Elijah_T_Du@manulife.com', 'name': 'Elijah.D'},
#      'message': ':sparkles: complete autoconfigure demo',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/xlaser4j/spring-all-demos/commits/f72377380590b95c16e2eed1ce7bfa7a690a5484'}]},
#   'public': True,
#   'created_at': '2019-12-03T02:34:56Z'},
#  {'id': '10995263207',
#   'type': 'PushEvent',
#   'actor': {'id': 17198282,
#    'login': 'shaoxiyan',
#    'display_login': 'shaoxiyan',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/shaoxiyan',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/17198282?'},
#   'repo': {'id': 171474558,
#    'name': 'shaoxiyan/Barron1200',
#    'url': 'https://api.github.com/repos/shaoxiyan/Barron1200'},
#   'payload': {'push_id': 4346740657,
#    'size': 2,
#    'distinct_size': 2,
#    'ref': 'refs/heads/master',
#    'head': 'f4487acf8da706b019fede3d1ff2a028104d667a',
#    'before': '2a1a371f9250e3f75f293437a537104017bc6ccc',
#    'commits': [{'sha': '36853690866c1dfc40fc984f1ba7f1c9b6d85dd9',
#      'author': {'email': 'admin@g497813927.com', 'name': '赵佳成'},
#      'message': 'Update sheet002.html\n\nUpdate version to aviod seeing garbled code for Chinese',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/shaoxiyan/Barron1200/commits/36853690866c1dfc40fc984f1ba7f1c9b6d85dd9'},
#     {'sha': 'f4487acf8da706b019fede3d1ff2a028104d667a',
#      'author': {'email': '1928578324@qq.com', 'name': '邵希言'},
#      'message': 'Merge pull request #4 from g497813927/master\n\nUpdate sheet002.html',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/shaoxiyan/Barron1200/commits/f4487acf8da706b019fede3d1ff2a028104d667a'}]},
#   'public': True,
#   'created_at': '2019-12-03T02:34:56Z'},
#  {'id': '10995263205',
#   'type': 'PushEvent',
#   'actor': {'id': 8517910,
#    'login': 'LombiqBot',
#    'display_login': 'LombiqBot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/LombiqBot',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8517910?'},
#   'repo': {'id': 46624936,
#    'name': 'Lombiq/Orchard-Liquid-Markup',
#    'url': 'https://api.github.com/repos/Lombiq/Orchard-Liquid-Markup'},
#   'payload': {'push_id': 4346740654,
#    'size': 0,
#    'distinct_size': 0,
#    'ref': 'refs/heads/issue/NEST-202',
#    'head': 'ff252e4865e603e68ca6a6d623318ba8bb7c8cf0',
#    'before': 'ff252e4865e603e68ca6a6d623318ba8bb7c8cf0',
#    'commits': []},
#   'public': True,
#   'created_at': '2019-12-03T02:34:56Z',
#   'org': {'id': 8158177,
#    'login': 'Lombiq',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/Lombiq',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8158177?'}},
#  {'id': '10995263204',
#   'type': 'CreateEvent',
#   'actor': {'id': 18423642,
#    'login': 'Bananaboat12',
#    'display_login': 'Bananaboat12',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Bananaboat12',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/18423642?'},
#   'repo': {'id': 225513492,
#    'name': 'Bananaboat12/Split-Reality',
#    'url': 'https://api.github.com/repos/Bananaboat12/Split-Reality'},
#   'payload': {'ref': 'master',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': 'A online cooperative puzzle game',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2019-12-03T02:34:56Z'}]

# %% [markdown]
# ### 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#
# * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
# * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)

# %%
r = requests.get('https://cat-fact.herokuapp.com/facts')
json.loads(r.text)
# Out:
# {'all': [{'_id': '5b4911940508220014ccfe94',
#    'text': 'By the time a cat is 9 years old, it will only have been awake for three years of its life.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 5,
#    'userUpvoted': None},
#   {'_id': '58e008b80aac31001185ed0d',
#    'text': 'Adult cats only meow to communicate with humans.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '58e009650aac31001185ed13',
#    'text': 'In the 1960s, the CIA tried to turn a cat into a bonafide spy by implanting a microphone into her ear and a radio transmitter at the base of her skull. She somehow survived the surgery but got hit by a taxi on her first mission.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '58e00b2b0aac31001185ed1f',
#    'text': "A cat has five toes on his front paws, and four on the back, unless he's a polydactyl.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '58e00be30aac31001185edfe',
#    'text': 'Cats use their whiskers to detect if they can fit through a space.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '58e00b4d0aac31001185ed22',
#    'text': 'Original kitty litter was made out of sand but it was replaced by more absorbent clay in 1948.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '5b199196ce456e001424256a',
#    'text': 'Cats can distinguish different flavors in water.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '5b1b411d841d9700146158d9',
#    'text': 'The Egyptian Mau’s name is derived from the Middle Egyptian word mjw, which means cat. But contrary to its name, it’s unclear whether the modern Egyptian Mau actually originated in Egypt.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '5b4912c60508220014ccfe99',
#    'text': 'Cats aren’t the only animals that purr — squirrels, lemurs, elephants, and even gorillas purr too.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '58e007db0aac31001185ecf7',
#    'text': 'There are cats who have survived falls from over 32 stories (320 meters) onto concrete.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '58e008800aac31001185ed07',
#    'text': 'Wikipedia has a recording of a cat meowing, because why not?',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '58e009790aac31001185ed14',
#    'text': 'The technical term for "hairball" is "bezoar."',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '58e00a120aac31001185ed17',
#    'text': "A cat's brain is 90% similar to a human's — more similar than to a dog's.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '591d9b2f227c1a0020d26823',
#    'text': 'Every year, nearly four million cats are eaten in China as a delicacy.',
#    'type': 'cat',
#    'user': {'_id': '587288f6e6f85e64ae1c7ef7',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '5974fb4dfedacb0020b5b4cc',
#    'text': 'Cats can survive falls from up to 65 feet or more.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '59a60ba66acf530020f35873',
#    'text': "Most cats don't like water because their coats do not insulate them well enough.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '5a4d76916ef087002174c28b',
#    'text': 'A cat’s nose pad is ridged with a unique pattern, just like the fingerprint of a human.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '59951d5ef2db18002031693c',
#    'text': 'America’s cats, including housecats that adventure outdoors and feral cats, kill between 1.3 billion and 4.0 billion birds in a year.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '5b01a447c6914f0014cc9a30',
#    'text': "The special sensory organ called the Jacobson's organ allows a cat to have 14 times the sense of smell of a human. It consists of two fluid-filled sacs that connect to the cat's nasal cavity and is located on the roof of their mouth behind their teeth.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '5b1b4014841d9700146158d0',
#    'text': 'In 1879, Belgium unsuccessfully tried to use cats to deliver mail.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '5b1b4055841d9700146158d3',
#    'text': 'Scottish sailer Alexander Selkirk once survived for 4 years on a deserted island thanks to feral cats that protected him from large rats during the night.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '5b3bd7d24cf4e10014bfd199',
#    'text': 'The myth that a cat has nine lives comes from their ability to jump and land from high places. The number 9 is believed by some to originate from William Shakespeare\'s Romeo and Juliet: "A cat has nine lives. For three he plays, for three he strays, and for the last three he stays."',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '5b453e380fd3a600147f32f3',
#    'text': 'Exposure to UV light with hairless or partially-hairless cats can result in sunburn, even during cloudy or shady conditions. If your cat risks overexposure, consider applying sunscreen daily.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '58e008780aac31001185ed05',
#    'text': 'Owning a cat can reduce the risk of stroke and heart attack by a third.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58f9b96132ffea00208fe9b7',
#    'text': 'rerewr',
#    'type': 'cat',
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '590b9d90229d260020af0b06',
#    'text': "Evidence suggests domesticated cats have been around since 3600 B.C., 2,000 years before Egypt's pharaohs.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58923f2fc3878c0011784c79',
#    'text': "I don't know anything about cats.",
#    'type': 'cat',
#    'user': {'_id': '5887e9f65c873e001103688d',
#     'name': {'first': 'Jackson', 'last': 'Sippe'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00b8b0aac31001185edf8',
#    'text': 'A cat can jump up to six times its length.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00c080aac31001185ee01',
#    'text': 'Cats only sweat through their foot pads.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '590c752b5363e000200d5141',
#    'text': "Kangaroos can't hop backwards",
#    'type': 'cat',
#    'user': {'_id': '590c74045363e000200d5140',
#     'name': {'first': 'Hampton', 'last': 'McGrath'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '599f89639a11040c4a163440',
#    'text': 'Here is a video of some cats in zero gravity. youtu.be/O9XtK6R1QAk',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '59cd7a97c828120020f7d3a1',
#    'text': 'Since cats treat us like cats and depend on us for things like food, water, and opening the door to let them out, they do recognize, that we are in some way in charge — the “big cat” in the shared territory. As territorial animals, our cats are constantly wondering why we’re not doing other cat things that the big cat would normally do in their territory. In fact, the “let me in, let me out, let me in” phenomenon is a good example. The bigger cat ostensibly rules the territory and therefore should be the one patrolling and marking it with pee so other cats stay away. But since humans don’t do this, indoor-outdoor cats reluctantly take on the role themselves. The apparent neuroticism of cats wanting to go outside every five minutes only to be let right back in is funny to us because it seems so silly and unnecessary. But to the cats, it’s very necessary (and frustrating) to cover for their dumb pals.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b1b40cc841d9700146158d7',
#    'text': 'In most US states, declawing cats is legal but in the European Union it is not.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b4911e60508220014ccfe95',
#    'text': 'A female cat is called a “molly” or a “queen”.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58cafac6ffae36001108d586',
#    'text': 'Cats have fur',
#    'type': 'cat',
#    'user': {'_id': '58c86fe52341fc0011d7b151',
#     'name': {'first': 'Alex', 'last': 'Simon'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e007cc0aac31001185ecf5',
#    'text': 'Cats are the most popular pet in the United States: There are 88 million pet cats and 74 million dogs.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e008510aac31001185ecfe',
#    'text': 'In tigers and tabbies, the middle of the tongue is covered in backward-pointing spines, used for breaking off and gripping meat.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e008c50aac31001185ed0e',
#    'text': "The world's richest cat is worth $13 million after his human passed away and left her fortune to him.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e008630aac31001185ed01',
#    'text': 'When cats grimace, they are usually "taste-scenting." They have an extra organ that, with some breathing control, allows the cats to taste-sense the air.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e008a30aac31001185ed0b',
#    'text': "A cat's purr may be a form of self-healing, as it can be a sign of nervousness as well as contentment.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e008d00aac31001185ed0f',
#    'text': 'Your cat recognizes your voice but just acts too cool to care (probably because they are).',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00a850aac31001185ed1a',
#    'text': 'Cats have a longer-term memory than dogs, especially when they learn by actually doing rather than simply seeing.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00b3a0aac31001185ed20',
#    'text': 'Polydactyl cats are also referred to as "Hemingway cats" because the author was so fond of them.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00b5f0aac31001185ed24',
#    'text': 'When asked if her husband had any hobbies, Mary Todd Lincoln is said to have replied "cats."',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00bdb0aac31001185edfd',
#    'text': 'Cats can change their meow to manipulate a human. They often imitate a human baby when they need food, for example.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00b820aac31001185edf7',
#    'text': "One legend claims that cats were created when a lion on Noah's Ark sneezed and two kittens came out.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '591d9bce227c1a0020d26827',
#    'text': 'In Korea and Japan, there is a Cat Cafe where you can go to drink coffee and hang out with cats for hours.',
#    'type': 'cat',
#    'user': {'_id': '587288f6e6f85e64ae1c7ef7',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00ba00aac31001185edfa',
#    'text': "When cats leave their poop uncovered, it is a sign of aggression to let you know they don't fear you.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '591d9bab227c1a0020d26825',
#    'text': 'Owning a cat can reduce the risk of heart attacks and strokes by more than a third, researchers found.',
#    'type': 'cat',
#    'user': {'_id': '587288f6e6f85e64ae1c7ef7',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '596e4989b863f300203102f4',
#    'text': 'Black cats are less likely to be adopted because of their "appearance".',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '59a60bae6acf530020f35875',
#    'text': 'Cats were mythic symbols of divinity in ancient Egypt.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '59d297b7c6671e0020957eb9',
#    'text': 'Kittens sleep so much because the growth hormone is only released when they sleep.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5a038d5a8e3dbc001f719791',
#    'text': 'Cats have 38 chromosomes in each zygote cell.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5a038dae8e3dbc001f719792',
#    'text': "Cucumbers look enough like a snake to cause a cat's instinctive fear of snakes to kick in, causing it to panic and flee.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5a36ec5fae877e0021ed79f5',
#    'text': 'It has been estimated that a cat yawns on the average of 109,500 times in his life.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5a4bfbbab0810f0021748b91',
#    'text': "Lil' Bunny Sue Roux is a cat who was born with no front legs, and walks upright like a kangaroo. https://www.instagram.com/lilbunnysueroux",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5a4d766c6ef087002174c288',
#    'text': 'Some Siamese cats appear cross-eyed because the nerves from the left side of the brain go to mostly the right eye and the nerves from the right side of the brain go mostly to the left eye. This causes some double vision, which the cat tries to correct by “crossing” its eyes.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b1b3feb841d9700146158cf',
#    'text': 'In Islam, cats are revered for their cleanliness. Muhammad is reported to have said that "a love of cats is an aspect of faith".',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b1b4065841d9700146158d4',
#    'text': 'A cat named Emmy lived aboard the RMS Empress of Ireland and she never missed a voyage. On May 28,1914, however, she refused to board. The ship left without her and then sank the following day.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b1b408a841d9700146158d5',
#    'text': 'Domestic cats will try not to drink from a water bowl that is next to their food. This is because in the wild, water next to their kill could be contaminated.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b3d8e4960d3890713ca39a8',
#    'text': 'A Chinese cat named Baidianr (meaning "white spot") had a unique ability to choose World Cup winners. He predicted the winner of the soccer competition 6 years in a row, before he died on June 2, 2018, just before the event ended.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b4909af0508220014ccfe8a',
#    'text': 'Cats have a layer called the tapetum lucidum just behind their retina which reflects light inside the eye, helping it capture more light. This reflected light is the glow you see when taking a photo of a cat with the flash on.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e009390aac31001185ed10',
#    'text': "Most cats are lactose intolerant, and milk can cause painful stomach cramps and diarrhea. It's best to forego the milk and just give your cat the standard: clean, cool drinking water.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5c6a105dc2d7a200140f69a0',
#    'text': 'When cats run, their backs contract and extend to give them maximum stride. Their shoulder blades are not attached with bone, but with muscle, and this gives a cat even greater extension and speed.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '59664b1f474ba80020ef8592',
#    'text': "Your cat's instincts tell her that a paperweight or knickknack could turn out to be a mouse. Her poking paw would send it scurrying, giving her a good game. This is probably why cats always seem to be knocking the glasses off your counter tops!",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '59669484bf604b00205c20e3',
#    'text': 'The fear of cats is called "Ailurophobia"',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '596f4f50a8d3440020e2d77d',
#    'text': 'Due to the controversy, though loved by most, the Kashmir is overlooked by many cat fanciers.',
#    'type': 'cat',
#    'user': {'_id': '596ea14ed4d9720020401f7b',
#     'name': {'first': 'Kenny', 'last': 'Corsig'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '59a60b896acf530020f3586d',
#    'text': 'Cat owners are 25% likely to pick George Harrison as their favorite Beatle.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '59a60b936acf530020f3586f',
#    'text': 'Only 11.5% of people consider themselves "cat people".',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '59a60b996acf530020f35870',
#    'text': '"Cat people" are 11% more likely to be introverted than others.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '59a60b9e6acf530020f35871',
#    'text': 'The Egyptian Mau is the oldest breed of cat, and is the fastest pedigreed cat.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '59b15b18d6eb960020d6767a',
#    'text': 'The place where Julius Caesar was murdered is now a cat sanctuary.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '59ceab6d5c87bf0020b94e0a',
#    'text': 'The Bombay cat breed was developed to resemble a miniature panther.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '59d297abc6671e0020957eb8',
#    'text': 'Cats use their whiskers to judge whether they’ll fit through a space.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a026058134ec2001f032f92',
#    'text': 'For a cat at rest, the average heart rate usually is between 150 and 180 bpm, more than twice that of a human, which averages 70 bpm.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a026092134ec2001f032f95',
#    'text': 'Compared to other felines, domestic cats have narrowly spaced canine teeth, adapted to their preferred prey of small rodents.',
#    'type': 'cat',
#    'user': {'_id': '587288f6e6f85e64ae1c7ef7',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a0260d1134ec2001f032f98',
#    'text': 'Cats, like dogs, are digitigrades. They walk directly on their toes, with the bones of their feet making up the lower part of the visible leg.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a038bb98e3dbc001f71978d',
#    'text': 'The domestic cat (Felis catus) is a small, typically furry, carnivorous mammal.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a038c178e3dbc001f71978e',
#    'text': "A cat's kidneys are so efficient, it can survive on a diet consisting only of meat, with no additional water, and can even rehydrate by drinking seawater.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a038c628e3dbc001f71978f',
#    'text': 'Most breeds of cat have a noted fondness for settling in high places, or perching. In the wild, a higher place may serve as a concealed site from which to hunt.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a038cdf8e3dbc001f719790',
#    'text': 'The ability of a cat to reflexively twist its body and balance itself during a fall is known as the "cat righting reflex".',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a038e188e3dbc001f719793',
#    'text': "The cat's tongue has backwards-facing spines about 500 μm long, which are called papillae. These contain keratin which makes them rigid so the papillae act like a hairbrush.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a038fba8e3dbc001f719794',
#    'text': 'Among domestic cats, males are more likely to fight than females.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a12460add20f9001fb45060',
#    'text': 'The softest part of a cat is most definitely its cheek area.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a21a9fb425e43002132f045',
#    'text': 'Hank the Cat was a Maine Coon feline that was put up as a joke candidate in the 2012 United States Senate election in Virginia, a feat which gained international coverage after Hank reportedly came third behind the two major candidates, including Vice Presidential candidate Tim Kaine.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a36eb68ae877e0021ed79f3',
#    'text': "When a cat yawns, it's mouth opens so wide that you can count every tooth.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a456246255f4b0021f54c04',
#    'text': 'A cat can die from essential oils',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4aab252c99ee00219e11c3',
#    'text': 'Cats can move their ears 180 degrees.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4aab2c2c99ee00219e11c4',
#    'text': "Hearing is the strongest of cat's senses: They can hear sounds as high as 64 kHz — compared with humans, who can hear only as high as 20 kHz.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4aab322c99ee00219e11c5',
#    'text': 'Cats have free-floating clavicle bones that attach their shoulders to their forelimbs, which allows them to squeeze through very small spaces.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4bfc91b0810f0021748b92',
#    'text': 'Blackie became the richest cat in history when he inherited 15 million British Pounds.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4bfcd3b0810f0021748b93',
#    'text': 'Colonel Meow, a Himalayan-Persian mix who became famous on social media websites for his extremely long fur and scowling face, holds the Guinness world record for longest hair on a cat (nine inches).',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4bfdf8b0810f0021748b94',
#    'text': 'Towser "The Mouser" of Glenturret Distillery in Crieff, Scotland, holds the Guinness World Record for the most mice caught (28,899).',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d75a38827521790281b99',
#    'text': 'A cat can’t climb head first down a tree because every claw on a cat’s paw points the same way. To get down from a tree, a cat must back down.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d75ac8827521790281b9a',
#    'text': 'The cat who holds the record for the longest non-fatal fall is Andy. He fell from the 16th floor of an apartment building (about 200 ft/.06 km) and survived.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d75e46ef087002174c284',
#    'text': 'Cats have about 130,000 hairs per square inch (20,155 hairs per square centimeter).',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d76106ef087002174c285',
#    'text': 'A cat’s eyesight is both better and worse than humans. It is better because cats can see in much dimmer light and they have a wider peripheral view. It’s worse because they don’t see color as well as humans do. Scientists believe grass appears red to cats.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d76516ef087002174c287',
#    'text': 'If they have ample water, cats can tolerate temperatures up to 133 °F.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d76736ef087002174c289',
#    'text': 'The lightest cat on record is a blue point Himalayan called Tinker Toy, who weighed 1 pound, 6 ounces (616 g). Tinker Toy was 2.75 inches (7 cm) tall and 7.5 inches (19 cm) long.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d767c6ef087002174c28a',
#    'text': 'Many Egyptians worshipped the goddess Bast, who had a woman’s body and a cat’s head.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d76b16ef087002174c28c',
#    'text': 'The first cartoon cat was Felix the Cat in 1919. In 1940, Tom and Jerry starred in the first theatrical cartoon “Puss Gets the Boot.” In 1981 Andrew Lloyd Weber created the musical Cats, based on T.S. Eliot’s Old Possum’s Book of Practical Cats.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d77446ef087002174c290',
#    'text': 'Approximately 1/3 of cat owners think their pets are able to read their minds.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d776e6ef087002174c291',
#    'text': 'The claws on the cat’s back paws aren’t as sharp as the claws on the front paws because the claws in the back don’t retract and, consequently, become worn.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d78136ef087002174c292',
#    'text': 'Like humans, cats tend to favor one paw over another.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d79016ef087002174c293',
#    'text': 'The most traveled cat is Hamlet, who escaped from his carrier while on a flight. He hid for seven weeks behind a panel on the airplane. By the time he was discovered, he had traveled nearly 373,000 miles (600,000 km).',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d79496ef087002174c294',
#    'text': 'Approximately 40,000 people are bitten by cats in the U.S. annually.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d79fb6ef087002174c295',
#    'text': 'The little tufts of hair in a cat’s ear that help keep out dirt direct sounds into the ear, and insulate the ears are called "ear furnishings."',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b085f85be3157001432164f',
#    'text': 'The Australian\xa0Wildlife\xa0Conservancy completed a 44km cat-proof fence in 2018 to prevent feral cats from entering the Newhaven wildlife sanctuary, who\xa0kill about a million native birds every night across Australia and have caused the extinction of 20 native species.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '59a60baa6acf530020f35874',
#    'text': 'Black cats are bad luck in the United States, but they are good luck in the United Kingdom and Australia.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a026087134ec2001f032f94',
#    'text': 'The cat skull is unusual among mammals in having very large eye sockets and a powerful and specialized jaw.',
#    'type': 'cat',
#    'user': {'_id': '587288f6e6f85e64ae1c7ef7',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4aab132c99ee00219e11c2',
#    'text': 'Cats have scent glands along their tail, their forehead, lips, chin, and the underside of their front paws.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4aab372c99ee00219e11c6',
#    'text': 'The french tuxedo kitty, Félix, aka "Astrocat", was the first cat to go to space. She survived the trip.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b0ecc7287c6b21e6fafdf01',
#    'text': 'A male cat is called a tom.',
#    'type': 'cat',
#    'user': {'_id': '587288f6e6f85e64ae1c7ef7',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b49110d0508220014ccfe91',
#    'text': 'Issac Newton decided to invent the cat flap because his own cat, Spithead, kept opening the door and spoiling his light experiments.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b4911340508220014ccfe92',
#    'text': 'Kittens start to dream when they’re about a week old.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b3fd8841d9700146158ce',
#    'text': 'Thank to an extremely efficient pair of kidneys, cats can hydrate themselves by drinking salt water.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c609ae8e54902001453303b',
#    'text': 'Approximately 40% of cats have a dominant paw. The rest are ambidextrous.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c69c3ecc2d7a200140f67eb',
#    'text': 'The average female housecat could give birth to ove 100 kittens in her lifetime.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c69c409c2d7a200140f67ec',
#    'text': 'Cats can have three litters a year, or approximately 12 kittens.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c69c422c2d7a200140f67ed',
#    'text': "Cats don't go through menopause, so they can continue to breed into their senior years.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b183fea64c2b20014b38f52',
#    'text': 'A cats whiskers are the exact width of their body.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b3f48841d9700146158cb',
#    'text': 'At night, Disneyland is overrun by cats. The theme park feeds them and takes care of them though, because they keep the rodent population in check.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b3f56841d9700146158cc',
#    'text': 'Cats lack antibodies against dog blood so they can only receive it via a transfusion once. The second time would kill them.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b3f6c841d9700146158cd',
#    'text': 'The Indiana State Prison allows prisoners to adopt a cat and keep it in their cell. They are meant to improve the mood of the prisoners.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b4022841d9700146158d1',
#    'text': "Oftentimes shelters won't let black cats be adopted around Halloween out of a fear that they may be sacrificed.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b4039841d9700146158d2',
#    'text': 'When cats bring dead animals back to their humans, they are "teaching them to hunt" as they would with a younger cat.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b4241841d9700146158da',
#    'text': 'Cat fanciers bred and exhibited Maus in Europe until World War II, when attention toward the cat waned and it nearly went extinct.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b455f841d9700146158db',
#    'text': 'The Egyptian Mau breed was saved from extinciton when Russian princess Natalie Trubetskaya was given a Mau that was imported from the Middle East. When she emigrated to New York City in 1956, she brought along three Mau cats. She used these kitties to establish the Fatima Egyptian Mau cattery, which produced many of the ancestors of today’s Egyptian Maus in America.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b4911770508220014ccfe93',
#    'text': 'Unlike kittens, adult cats don’t release any particular key hormones during sleep. They snooze all day just because they can. :)',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b4912650508220014ccfe98',
#    'text': "Russian scientists discovered in the 1930s that Siamese kittens kept in very warm rooms didn't develop the breed's signature dark patches.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b4912000508220014ccfe96',
#    'text': 'Cats have a third eyelid called a “haw”. It’s generally only visible when they’re unwell.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b4912320508220014ccfe97',
#    'text': 'In the original Italian version of Cinderella, the benevolent fairy godmother figure was a cat.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '58e008450aac31001185ecfd',
#    'text': 'A cat was mayor of Talkeetna, Alaska, for 20 years. His name is Stubbs, and he died on July 23, 2017.',
#    'type': 'cat',
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3551458e0b8d00148d45e3',
#    'text': 'Many people think that the Turkish Van is simply a color variation of the Turkish Angora, but in fact, they are distinct breeds that developed in different parts of Turkey.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3551d48e0b8d00148d45e4',
#    'text': 'The Bengal is the result of crossbreeding between domestic cats and Asian leopard cats, and its name is derived from the scientific name for the Asian leopard cat (Felis bengalensis).',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3552058e0b8d00148d45e5',
#    'text': 'Despite its traditionally wild roots, the Bengal is domestic and will gladly make itself in the indoor "jungle" of your home.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3552738e0b8d00148d45e6',
#    'text': "Cat's cannot see in total darkness, however their vision is much better than a human's in semidarkness because their retinas are much more sensitive to light.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c35531e8e0b8d00148d45e8',
#    'text': "If you grow your own catnip, here's how to prepare it for kitty's enjoyment: Cut several stalks of the plant from the base. Hang them upside down in a dark and dry room for several weeks. Then cut the catnip into small pieces, rub some on your cat's favorite toys or scratching post, and let the games begin!",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3bba466bd7ea00141eff4f',
#    'text': 'Approximately 80% of orange tabbies are male.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3bbab76bd7ea00141eff50',
#    'text': 'If you need to trim a cat\'s nails, choose a moment when he is relaxed. Massage his paws gently before clipping. Make sure you\'re using a pair of clippers specifically for cat\'s nails, not human nail clippers. Avoid cutting the nail too close to the "quick," the pink part of a cat\'s nail, which is full of blood vessels and nerves.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3bbb236bd7ea00141eff53',
#    'text': 'The gene that codes orange fur is on the X chromosome, so female cats must inherit two orange genes to end up with orange fur, while male cats only need one.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c470572a99c3f00140fe4bd',
#    'text': 'Cats like being brushed by their owners, because it reminds them of their mother.',
#    'type': 'cat',
#    'user': {'_id': '5c470492a99c3f00140fe4bc',
#     'name': {'first': 'David', 'last': 'Gippner'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c471b30a99c3f00140fe4c5',
#    'text': 'The collective noun for kittens is a "kindle".',
#    'type': 'cat',
#    'user': {'_id': '5c471b15a99c3f00140fe4c4',
#     'name': {'first': 'Beth', 'last': 'Rothwell'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c475c86a99c3f00140fe4cf',
#    'text': "The Manx hails from the Isle of Man in the Irish Sea, and many Manx are tailless, a condition believed to have been caused by a dominant genetic mutation that spread among the island's cat population.",
# ...
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b27b0f1c57001592f12f',
#    'type': 'cat',
#    'text': 'The Norwegian Forest Cat is called "skogcatt" in its homeland of Norway and plays a role in the Norwegian fairy tales and legends.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b29f0f1c57001592f130',
#    'type': 'cat',
#    'text': 'The Abyssinian, the Siamese, and the American Shorthair were crossbred to produce the Ocicat breed.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b5b50f1c57001592f131',
#    'type': 'cat',
#    'text': 'Andy Warhol amassed quite the collection of feline friends during his lifetime, beginning with a Siamese cat named Hester that was given to him by actress Gloria Swanson. By breeding Hester with a cat named Sam, Warhol ended up with multiple litters of kittens, at one point housing 25 cats in his Upper East Side townhouse in NYC.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b6090f1c57001592f132',
#    'type': 'cat',
#    'text': 'While two kittens might sound like double trouble, adopting two at a time can actually make your job easier. Two cans can keep each other company, reducing their need for socialization, and they will expend energy by playing together. Kittens in the same litter often form tight sibling bonds.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b6280f1c57001592f133',
#    'type': 'cat',
#    'text': 'Some animal shelters require kittens be adopted in pairs to ensure they came from the same litter.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b64e0f1c57001592f134',
#    'type': 'cat',
#    'text': 'The Havana Brown breed hails from England, where it was created by crossbreeding Siamese cats with domestic black cats.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b69a0f1c57001592f135',
#    'type': 'cat',
#    'text': "While we don't know the exact origins of the Russian Blue, it's commonly believed the breed comes from the Archangel Isles in northwestern Russia—the region's cold climate would certainly explain the breed's plush coat.",
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b6f10f1c57001592f136',
#    'type': 'cat',
#    'text': "Traveling with cats can be stressful for everyone involved. Whether you're taking a kitty to the vet, or on a road trip, or on a flight, there are things you can do to help her stay relaxed in the carrier. Pet shops sell calming treats and sprays that can reduce a cat's anxiety. It might also help to put a beloved toy or a blanket in the carrier.",
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b7170f1c57001592f137',
#    'type': 'cat',
#    'text': 'The wild-looking but domestic Ocicat is named for its resemblance to the ocelot, a small South American wild cat.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38bb910f1c57001592f14e',
#    'type': 'cat',
#    'text': 'Dr. Seuss wrote The Cat in the Hat using only 236 words.',
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d4a4fc6b6c1290015d43471',
#    'type': 'cat',
#    'text': 'Cats are the most interesting mammals on earth.',
#    'user': {'_id': '5d4a4fa4b6c1290015d43470',
#     'name': {'first': 'Yvette', 'last': 'Johnson-Rodgers'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d8a61992c54210015bf6076',
#    'type': 'cat',
#    'text': '"Cats "knead" because of seperation from their mothers".',
#    'user': {'_id': '5d70057df83a9d00155de899',
#     'name': {'first': 'Yang', 'last': 'Zhang'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d9c556168a764001553b382',
#    'type': 'cat',
#    'text': 'A cat has 244 bones in its entire body—even more than a human, who only has 206 bones.',
#    'user': {'_id': '5d84ce8abf541a0015b5febb',
#     'name': {'first': 'Veronika', 'last': 'Koval'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d9d4ae168a764001553b388',
#    'type': 'cat',
#    'text': 'Cats conserve energy by sleeping for an average of 13 to14 hours a day.',
#    'user': {'_id': '5d9d4a4468a764001553b387',
#     'name': {'first': 'Erick', 'last': 'Vazquez'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5db2bd49085bcb0015750662',
#    'type': 'cat',
#    'text': 'All cats are grey at night.',
#    'user': {'_id': '5db2bcbe085bcb0015750661',
#     'name': {'first': 'Владимир', 'last': 'А'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d9cf25868a764001553b386',
#    'type': 'cat',
#    'text': 'XYZ.',
#    'user': {'_id': '5d9cf24e68a764001553b385',
#     'name': {'first': 'Mateusz', 'last': 'Głowacki'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5daee7dbec4a6500156d2e6d',
#    'type': 'cat',
#    'text': 'Test.',
#    'user': {'_id': '5da41b7504ce7e001534bfa1',
#     'name': {'first': 'mohammed', 'last': 'aljundi'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38baf20f1c57001592f14b',
#    'type': 'cat',
#    'text': "The stationmaster of the Kishi rail station in western Japan until 2015 was a cat named Tama. The calico cat wore a stationmaster's cap and greeted visitors by the ticket gate. After her death, Tama was elevated to the status of a goddess in a Shinto-style funeral.",
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bb440f1c57001592f14c',
#    'type': 'cat',
#    'text': "It's important for cats to have regular ear exams—this is something you can do at home! Gently fold back the ears and look into the ear canal. The inner ear should be pale pink with little to no earwax. If you notice redness, swelling, discharge, or a lot of earwax, it's time to see a veterinarian.",
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bb7a0f1c57001592f14d',
#    'type': 'cat',
#    'text': 'In Norse mythology, the goddess Freya travels in a chariot pulled by two cats—specifically Norwegian Forest Cats.',
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bbb20f1c57001592f14f',
#    'type': 'cat',
#    'text': 'American Curl kittens are born with straight ears, but the ears begin to curl back after just a few days.',
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bc0c0f1c57001592f150',
#    'type': 'cat',
#    'text': "If your cat licks from the toilet, bathtub, or sink, she may be telling you something about the water bowl. Make sure it's clean, replace the water regularly to keep it from getting stale or developing a film on top, and if necessary, get a new bowl. Some cats prefer glass bowls to plastic.",
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bc630f1c57001592f151',
#    'type': 'cat',
#    'text': "Georgia O'Keeffe was a celebrated painter, a figurehead of American modernism, a fashion icon, and... a cat owner! O'Keeffe kept a number of animals at her home in New Mexico, including her pet Siamese cat, who appears alongside O'Keeffe in a portrait shot by photographer John Candelario.",
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bc970f1c57001592f152',
#    'type': 'cat',
#    'text': 'The pink substance inside a cat\'s nail is called the "quick" or the "dermis". When trimming your cat\'s nails, be sure to only cut the upper white part of the nail, not the quick.',
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bcc00f1c57001592f153',
#    'type': 'cat',
#    'text': 'The irresistable and cuddly Ragamuffin is the result of crossbreeding Ragdoll cats with Persians, Himalayans, and other larger longhaired breeds.',
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bd180f1c57001592f154',
#    'type': 'cat',
#    'text': 'Cats are among only a few animals that walk by moving their two right legs one after another and then their two left legs, rather than moving diagonal limbs simultaneously. Giraffes and camels also have this quality.',
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bd750f1c57001592f155',
#    'type': 'cat',
#    'text': "Legend holds that a goddess rewarded a temple cat's piety by turning the cat's eyes blue and his coat golden, thus creating the first Birman cat.",
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bdab0f1c57001592f156',
#    'type': 'cat',
#    'text': "While some cats love being brushed, others don't take to it naturally. Try to groom your cat in the same spot at the same time of day to create a sense of routine.",
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38be200f1c57001592f157',
#    'type': 'cat',
#    'text': 'The Turkish Van is often called the "swimming cat" because they are naturals in the water, thanks in part to their uniquely textured, water-resistant coat.',
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38be370f1c57001592f158',
#    'type': 'cat',
#    'text': 'Kittens typically begin to engage in playful behavior at around four weeks of age.',
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d3e2191484b54001508b0df',
#    'type': 'cat',
#    'text': 'Cats can be nation president.',
#    'user': {'_id': '5d3dedfa484b54001508b0de',
#     'name': {'first': 'Jonathan', 'last': 'Velazquez'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d4878cca994550015e6ca0a',
#    'type': 'cat',
#    'text': 'Horse.',
#    'user': {'_id': '5d48783ca994550015e6ca09',
#     'name': {'first': 'Artemiy', 'last': 'Pyatakov'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d5dc687b155490015c5663f',
#    'type': 'cat',
#    'text': 'The cats are fools.',
#    'user': {'_id': '5d5dc631b155490015c5663e',
#     'name': {'first': 'Martin', 'last': 'Paredez'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d736a9617cd6300154df550',
#    'type': 'cat',
#    'text': 'A.',
#    'user': {'_id': '5d736a7817cd6300154df54f',
#     'name': {'first': 'Ade', 'last': 'Suluh'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d839adc8a86520015f44f8e',
#    'type': 'cat',
#    'text': 'Cats purr.',
#    'user': {'_id': '5d839a818a86520015f44f8d',
#     'name': {'first': 'Ju', 'last': 'Lia'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d91fc7cc586ca0015c71695',
#    'type': 'cat',
#    'text': 'GG.',
#    'user': {'_id': '5d91fc56c586ca0015c71694',
#     'name': {'first': '기웅', 'last': '김'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d94d26c6845b800156579b5',
#    'type': 'cat',
#    'text': 'Gatos.',
#    'user': {'_id': '5d94d25c6845b800156579b4',
#     'name': {'first': 'Dave', 'last': 'More'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d9bd688f98b610015c25ee2',
#    'type': 'cat',
#    'text': 'Is this a dumb app?.',
#    'user': {'_id': '5d9bd5b9f98b610015c25edf',
#     'name': {'first': 'Digggid', 'last': 'Tsar'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5daa121c79186100154250be',
#    'type': 'cat',
#    'text': 'Dr. Bootsy Calico love cats, he was raised by cats. He is the main antagonist in The Boss Baby: Back in Business.',
#    'user': {'_id': '5daa103779186100154250bd',
#     'name': {'first': 'Daniel', 'last': 'Carvalho'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5daa192179186100154250c4',
#    'type': 'cat',
#    'text': 'GitHub is a cloud source version control system where its mascot is an octocat, an anthropomorphized cat with five tentacles.',
#    'user': {'_id': '5daa103779186100154250bd',
#     'name': {'first': 'Daniel', 'last': 'Carvalho'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5daed556ec4a6500156d2e6c',
#    'type': 'cat',
#    'text': 'One of the biggest pilgrimage sites in the middle ages was the cathedral of Caterbury.',
#    'user': {'_id': '5daec340ec4a6500156d2e6b',
#     'name': {'first': 'jo', 'last': 'ne'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5db6ac1ab5f3720015400ea4',
#    'type': 'cat',
#    'text': 'Cats have fur.',
#    'user': {'_id': '5db6ac04b5f3720015400ea3',
#     'name': {'first': 'Deekay', 'last': 'Em'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5db9577511880200157ad78a',
#    'type': 'cat',
#    'text': 'Testing bro.',
#    'user': {'_id': '5db956e711880200157ad783',
#     'name': {'first': 'Test', 'last': 'test'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5db9bf3511880200157ad78e',
#    'type': 'cat',
#    'text': 'A cat has been known to beg for food even when there already is food in its bowl.',
#    'user': {'_id': '5db9beb211880200157ad78d',
#     'name': {'first': 'Nick', 'last': 'Hyland'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5dc944f5353d620015a71ce0',
#    'type': 'cat',
#    'text': "I got 3 cat and i'm allergic to them.",
#    'user': {'_id': '5dc944d7353d620015a71cdf',
#     'name': {'first': 'João', 'last': 'Guerreiro'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5dd21b91a960ba0015a66895',
#    'type': 'cat',
#    'text': 'The technical term for a cat’s hairball is a “bezoar.”.',
#    'user': {'_id': '5dd21b29a960ba0015a66894',
#     'name': {'first': 'Gabriel', 'last': 'Lien'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5dd3a48821bcaf0015eaa854',
#    'type': 'cat',
#    'text': 'Cats named Meowduri are cute.',
#    'user': {'_id': '5dd3a45921bcaf0015eaa851',
#     'name': {'first': 'Aaqib', 'last': 'Ismail'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5dd401d08f1fb70015b894ad',
#    'type': 'cat',
#    'text': "Cat's are not dogs.",
#    'user': {'_id': '5dd401b88f1fb70015b894ac',
#     'name': {'first': 'Ronnie', 'last': 'Kilsbo'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5ddd252f3e2c6c0015051ac2',
#    'type': 'cat',
#    'text': 'That cat can be the killer of mom.',
#    'user': {'_id': '5ddd14d23e2c6c0015051ac1',
#     'name': {'first': 'FATİH', 'last': 'KESER'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5de0a5d32abaa900154956c9',
#    'type': 'cat',
#    'text': 'This is the first time.',
#    'user': {'_id': '5de0a5b02abaa900154956c8',
#     'name': {'first': 'Sushen', 'last': 'Biswas'}},
#    'upvotes': 0,
#    'userUpvoted': None}]}

# %%
r = requests.get('http://odata.wra.gov.tw/v4/RealtimeWaterLevel')
json.loads(r.text)
# Out:
# {'@odata.context': 'http://odata.wra.gov.tw/v4/$metadata#RealtimeWaterLevel',
#  '@odata.count': 100,
#  'value': [{'StationIdentifier': '2420H046',
#    'RecordTime': 'Dec 2, 2019 5:40:00 PM',
#    'WaterLevel': 35.97},
#   {'StationIdentifier': '1670H003',
#    'RecordTime': 'Dec 2, 2019 5:40:00 PM',
#    'WaterLevel': 0.23},
#   {'StationIdentifier': '1850H004',
#    'RecordTime': 'Dec 2, 2019 5:40:00 PM',
#    'WaterLevel': 72.06},
#   {'StationIdentifier': '1650H010',
#    'RecordTime': 'Dec 2, 2019 5:40:00 PM',
#    'WaterLevel': 0.24},
#   {'StationIdentifier': '2560H023',
#    'RecordTime': 'Dec 2, 2019 5:40:00 PM',
#    'WaterLevel': 12.98},
#   {'StationIdentifier': '1740H009',
#    'RecordTime': 'Dec 2, 2019 5:40:00 PM',
#    'WaterLevel': 32.31},
#   {'StationIdentifier': '2200H020',
#    'RecordTime': 'Dec 2, 2019 5:40:00 PM',
#    'WaterLevel': 318.16},
#   {'StationIdentifier': '1630H040',
#    'RecordTime': 'Dec 2, 2019 5:40:00 PM',
#    'WaterLevel': 1.74},
#   {'StationIdentifier': '1660H012',
#    'RecordTime': 'Dec 2, 2019 5:40:00 PM',
#    'WaterLevel': 0.14},
#   {'StationIdentifier': '2560H006',
#    'RecordTime': 'Dec 2, 2019 5:40:00 PM',
#    'WaterLevel': 3.09},
#   {'StationIdentifier': '1730H069',
#    'RecordTime': 'Dec 2, 2019 5:40:00 PM',
#    'WaterLevel': 140.95},
#   {'StationIdentifier': '1850H005',
#    'RecordTime': 'Dec 2, 2019 5:40:00 PM',
#    'WaterLevel': 22.12},
#   {'StationIdentifier': '1650H008',
#    'RecordTime': 'Dec 2, 2019 5:40:00 PM',
#    'WaterLevel': 0.31},
#   {'StationIdentifier': '1660H010',
#    'RecordTime': 'Dec 2, 2019 5:40:00 PM',
#    'WaterLevel': 7.44},
#   {'StationIdentifier': '1630H037',
#    'RecordTime': 'Dec 2, 2019 5:40:00 PM',
#    'WaterLevel': 9.31},
#   {'StationIdentifier': '1580H015',
#    'RecordTime': 'Dec 2, 2019 5:40:00 PM',
#    'WaterLevel': 22.52},
#   {'StationIdentifier': '1630H029',
#    'RecordTime': 'Dec 2, 2019 5:20:00 PM',
#    'WaterLevel': 4.96},
#   {'StationIdentifier': '1680H004',
#    'RecordTime': 'Dec 2, 2019 5:40:00 PM',
#    'WaterLevel': 1.1},
#   {'StationIdentifier': '1630H031',
#    'RecordTime': 'Dec 2, 2019 5:20:00 PM',
#    'WaterLevel': 0.53},
#   {'StationIdentifier': '1650H015',
#    'RecordTime': 'Dec 2, 2019 5:40:00 PM',
#    'WaterLevel': 0.17},
#   {'StationIdentifier': '1630H034',
#    'RecordTime': 'Dec 2, 2019 5:20:00 PM',
#    'WaterLevel': 278.37},
#   {'StationIdentifier': '1550H012',
#    'RecordTime': 'Dec 2, 2019 5:40:00 PM',
#    'WaterLevel': 0.55},
#   {'StationIdentifier': '1630H018',
#    'RecordTime': 'Dec 2, 2019 5:40:00 PM',
#    'WaterLevel': 10},
#   {'StationIdentifier': '1540H030',
#    'RecordTime': 'Dec 2, 2019 5:40:00 PM',
#    'WaterLevel': 27.17},
#   {'StationIdentifier': '1630H027',
#    'RecordTime': 'Dec 2, 2019 5:20:00 PM',
#    'WaterLevel': 26.13},
#   {'StationIdentifier': '1650H012',
#    'RecordTime': 'Dec 2, 2019 5:40:00 PM',
#    'WaterLevel': 0.7},
#   {'StationIdentifier': '1630H025',
#    'RecordTime': 'Dec 2, 2019 5:40:00 PM',
#    'WaterLevel': 1.48},
#   {'StationIdentifier': '2200H029',
#    'RecordTime': 'Dec 2, 2019 5:40:00 PM',
#    'WaterLevel': 145.15},
#   {'StationIdentifier': '1540H039',
#    'RecordTime': 'Dec 2, 2019 5:40:00 PM',
#    'WaterLevel': 38.98},
#   {'StationIdentifier': '1590H016',
#    'RecordTime': 'Dec 2, 2019 5:40:00 PM',
#    'WaterLevel': 11.26},
#   {'StationIdentifier': '1540H009',
#    'RecordTime': 'Dec 2, 2019 5:40:00 PM',
#    'WaterLevel': 1.07},
#   {'StationIdentifier': '1630H023',
#    'RecordTime': 'Dec 2, 2019 5:40:00 PM',
#    'WaterLevel': 0.16},
#   {'StationIdentifier': '1630H035',
#    'RecordTime': 'Dec 2, 2019 5:20:00 PM',
#    'WaterLevel': 402.45},
#   {'StationIdentifier': '1510H058',
#    'RecordTime': 'Dec 2, 2019 5:40:00 PM',
#    'WaterLevel': 12.22},
#   {'StationIdentifier': '2200H025',
#    'RecordTime': 'Dec 2, 2019 5:40:00 PM',
#    'WaterLevel': 207.14},
#   {'StationIdentifier': '1540H037',
#    'RecordTime': 'Dec 2, 2019 5:40:00 PM',
#    'WaterLevel': 31.99},
#   {'StationIdentifier': '1590H015',
#    'RecordTime': 'Dec 2, 2019 5:40:00 PM',
#    'WaterLevel': 9.29},
#   {'StationIdentifier': '1510H086',
#    'RecordTime': 'Dec 2, 2019 5:40:00 PM',
#    'WaterLevel': 317.98},
#   {'StationIdentifier': '1590H012',
#    'RecordTime': 'Dec 2, 2019 5:40:00 PM',
#    'WaterLevel': 2.76},
#   {'StationIdentifier': '1510H080',
#    'RecordTime': 'Dec 2, 2019 5:40:00 PM',
#    'WaterLevel': 1068.95},
#   {'StationIdentifier': '1430H056',
#    'RecordTime': 'Dec 2, 2019 5:40:00 PM',
#    'WaterLevel': 79.83},
#   {'StationIdentifier': '2200H011',
#    'RecordTime': 'Dec 2, 2019 5:40:00 PM',
#    'WaterLevel': 25.62},
#   {'StationIdentifier': '1540H033',
#    'RecordTime': 'Dec 2, 2019 5:40:00 PM',
#    'WaterLevel': 23.28},
#   {'StationIdentifier': '1580H022',
#    'RecordTime': 'Dec 2, 2019 5:40:00 PM',
#    'WaterLevel': 0.57},
#   {'StationIdentifier': '1730H077',
#    'RecordTime': 'Dec 2, 2019 5:40:00 PM',
#    'WaterLevel': 740.46},
#   {'StationIdentifier': '1430H051',
#    'RecordTime': 'Dec 2, 2019 5:40:00 PM',
#    'WaterLevel': 95.66},
#   {'StationIdentifier': '1510H050',
#    'RecordTime': 'Dec 2, 2019 5:40:00 PM',
#    'WaterLevel': 155.53},
#   {'StationIdentifier': '1430H052',
#    'RecordTime': 'Dec 2, 2019 5:40:00 PM',
#    'WaterLevel': 173.07},
#   {'StationIdentifier': '1510H082',
#    'RecordTime': 'Dec 2, 2019 5:40:00 PM',
#    'WaterLevel': 752.39},
#   {'StationIdentifier': '1510H087',
#    'RecordTime': 'Dec 2, 2019 5:40:00 PM',
#    'WaterLevel': 428.66},
#   {'StationIdentifier': '1580H001',
#    'RecordTime': 'Dec 2, 2019 5:40:00 PM',
#    'WaterLevel': 224.2},
#   {'StationIdentifier': '1630H005',
#    'RecordTime': 'Dec 2, 2019 5:40:00 PM',
#    'WaterLevel': 39.77},
#   {'StationIdentifier': '1430H030',
#    'RecordTime': 'Dec 2, 2019 5:40:00 PM',
#    'WaterLevel': 87.44},
#   {'StationIdentifier': '1430H061',
#    'RecordTime': 'Dec 2, 2019 5:40:00 PM',
#    'WaterLevel': 24.98},
#   {'StationIdentifier': '1430H047',
#    'RecordTime': 'Dec 2, 2019 5:40:00 PM',
#    'WaterLevel': 72.36},
#   {'StationIdentifier': '1510H075',
#    'RecordTime': 'Dec 3, 2019 9:10:00 AM',
#    'WaterLevel': 346.5},
#   {'StationIdentifier': '1510H084',
#    'RecordTime': 'Dec 2, 2019 5:40:00 PM',
#    'WaterLevel': 145},
#   {'StationIdentifier': '1430H037',
#    'RecordTime': 'Dec 2, 2019 5:40:00 PM',
#    'WaterLevel': 380.48},
#   {'StationIdentifier': '1580H018',
#    'RecordTime': 'Dec 2, 2019 5:40:00 PM',
#    'WaterLevel': 21.24},
#   {'StationIdentifier': '1430H028',
#    'RecordTime': 'Dec 2, 2019 5:40:00 PM',
#    'WaterLevel': 23.59},
#   {'StationIdentifier': '1430H058',
#    'RecordTime': 'Dec 2, 2019 5:40:00 PM',
#    'WaterLevel': 83.09},
#   {'StationIdentifier': '1430H046',
#    'RecordTime': 'Dec 2, 2019 5:40:00 PM',
#    'WaterLevel': 111.07},
#   {'StationIdentifier': '1510H063',
#    'RecordTime': 'Dec 3, 2019 9:10:00 AM',
#    'WaterLevel': 263.83},
#   {'StationIdentifier': '1350H029',
#    'RecordTime': 'Dec 2, 2019 5:40:00 PM',
#    'WaterLevel': 175.92},
#   {'StationIdentifier': '1420H052',
#    'RecordTime': 'Dec 2, 2019 5:30:00 PM',
#    'WaterLevel': 429.63},
#   {'StationIdentifier': '1580H008',
#    'RecordTime': 'Dec 2, 2019 5:40:00 PM',
#    'WaterLevel': 19.4},
#   {'StationIdentifier': '1420H058',
#    'RecordTime': 'Dec 2, 2019 5:40:00 PM',
#    'WaterLevel': 440.49},
#   {'StationIdentifier': '1430H054',
#    'RecordTime': 'Dec 2, 2019 5:40:00 PM',
#    'WaterLevel': 48.35},
#   {'StationIdentifier': '1430H040',
#    'RecordTime': 'Dec 2, 2019 5:40:00 PM',
#    'WaterLevel': 19.43},
#   {'StationIdentifier': '1340H013',
#    'RecordTime': 'Dec 2, 2019 5:50:00 PM',
#    'WaterLevel': 247.03},
#   {'StationIdentifier': '1350H020',
#    'RecordTime': 'Dec 2, 2019 5:50:00 PM',
#    'WaterLevel': 220.77},
#   {'StationIdentifier': '1400H020',
#    'RecordTime': 'Dec 2, 2019 5:40:00 PM',
#    'WaterLevel': 318.71},
#   {'StationIdentifier': '1550H017',
#    'RecordTime': 'Dec 2, 2019 5:40:00 PM',
#    'WaterLevel': 15.7},
#   {'StationIdentifier': '1420H056',
#    'RecordTime': 'Dec 2, 2019 4:30:00 PM',
#    'WaterLevel': 196.5},
#   {'StationIdentifier': '1340H011',
#    'RecordTime': 'Dec 2, 2019 5:50:00 PM',
#    'WaterLevel': 7.31},
#   {'StationIdentifier': '1290H004',
#    'RecordTime': 'Dec 2, 2019 5:40:00 PM',
#    'WaterLevel': 115.62},
#   {'StationIdentifier': '1340H009',
#    'RecordTime': 'Dec 2, 2019 5:40:00 PM',
#    'WaterLevel': 175.83},
#   {'StationIdentifier': '1350H017',
#    'RecordTime': 'Dec 2, 2019 5:50:00 PM',
#    'WaterLevel': 243.83},
#   {'StationIdentifier': '1400H018',
#    'RecordTime': 'Dec 2, 2019 5:40:00 PM',
#    'WaterLevel': 55.21},
#   {'StationIdentifier': '1540H035',
#    'RecordTime': 'Dec 2, 2019 5:40:00 PM',
#    'WaterLevel': 86.68},
#   {'StationIdentifier': '1140H107',
#    'RecordTime': 'Dec 2, 2019 5:50:00 PM',
#    'WaterLevel': 2.55},
#   {'StationIdentifier': '1300H024',
#    'RecordTime': 'Dec 2, 2019 5:40:00 PM',
#    'WaterLevel': 28.84},
#   {'StationIdentifier': '1140H128',
#    'RecordTime': 'Dec 2, 2019 5:50:00 PM',
#    'WaterLevel': 22.05},
#   {'StationIdentifier': '1310H002',
#    'RecordTime': 'Dec 2, 2019 5:50:00 PM',
#    'WaterLevel': 1.01},
#   {'StationIdentifier': '1350H016',
#    'RecordTime': 'Dec 2, 2019 5:40:00 PM',
#    'WaterLevel': 98.24},
#   {'StationIdentifier': '1400H009',
#    'RecordTime': 'Dec 2, 2019 5:40:00 PM',
#    'WaterLevel': 191.53},
#   {'StationIdentifier': '1420H054',
#    'RecordTime': 'Dec 2, 2019 5:40:00 PM',
#    'WaterLevel': 704.2},
#   {'StationIdentifier': '1140H101',
#    'RecordTime': 'Dec 2, 2019 5:40:00 PM',
#    'WaterLevel': 182},
#   {'StationIdentifier': '1300H021',
#    'RecordTime': 'Dec 2, 2019 5:50:00 PM',
#    'WaterLevel': 0.37},
#   {'StationIdentifier': '1140H098',
#    'RecordTime': 'Dec 2, 2019 5:30:00 PM',
#    'WaterLevel': 174.52},
#   {'StationIdentifier': '1300H014',
#    'RecordTime': 'Dec 2, 2019 5:50:00 PM',
#    'WaterLevel': 208.94},
#   {'StationIdentifier': '1140H126',
#    'RecordTime': 'Dec 2, 2019 5:40:00 PM',
#    'WaterLevel': 80.97},
#   {'StationIdentifier': '1140H058',
#    'RecordTime': 'Dec 3, 2019 9:10:00 AM',
#    'WaterLevel': 4.55},
#   {'StationIdentifier': '1350H030',
#    'RecordTime': 'Dec 2, 2019 5:40:00 PM',
#    'WaterLevel': 57.5},
#   {'StationIdentifier': '1340H016',
#    'RecordTime': 'Dec 2, 2019 5:40:00 PM',
#    'WaterLevel': 0.69},
#   {'StationIdentifier': '1140H076',
#    'RecordTime': 'Dec 3, 2019 9:10:00 AM',
#    'WaterLevel': 135.48},
#   {'StationIdentifier': '2560H025',
#    'RecordTime': 'Dec 2, 2019 5:00:00 PM',
#    'WaterLevel': 3.08},
#   {'StationIdentifier': '1730H076',
#    'RecordTime': 'Dec 2, 2019 5:40:00 PM',
#    'WaterLevel': 58.07},
#   {'StationIdentifier': '1730H065',
#    'RecordTime': 'Dec 2, 2019 5:40:00 PM',
#    'WaterLevel': 90.67},
#   {'StationIdentifier': '2420H024',
#    'RecordTime': 'Dec 2, 2019 5:40:00 PM',
#    'WaterLevel': 4.74}],
#  '@odata.nextLink': 'http://odata.wra.gov.tw/v4/RealtimeWaterLevel?$skip=100&$top=100'}
